# %% [markdown]
# # css technique for aligning decimals.
#
# all of my recent plotting techniques rely on access to cell values in css.
# when we have the values in css, along with their extent (min/max), we can adjust
# the values using math to align decimal points.
#
# decimal point aligned is important in scanning documents and [improving low numeracy experiences](https://accessiblenumbers.com/).
#
# disclaimer: this technique use css `log` and [`sign`](https://developer.mozilla.org/en-US/docs/Web/CSS/sign#browser_compatibility). [can i use `sign`](https://caniuse.com/?search=sign()) indicates the function lacks broad support only works in firefox and safari which limits the application of this technique.

# %%
# %%
# our approach is to calculate the order of magnitude of our values and their sign on a monospace font.
# we only need the maximum number of digits and signs before the decimal;
# we'll refer to these values with the prefix `--tens`
#
#     display\
# ```css
# #aligned {
#     font-family: monospace;
#     --tens-max: calc(
#         round(up, max(1, log(abs(var(--0-max)), 10)))
#         + abs(min(0, sign(var(--0-max))))
#     );
#     --tens-min: calc(
#         round(up, max(1, log(abs(var(--0-min)), 10)))
#         + abs(min(0, sign(var(--0-min))))
#     );
#     --tens-total: calc(max(var(--tens-max), var(--tens-min)));
# ```
# insert a pseudo-element in each table cell that using `1ch` spaces -
# [Relative to the width of the "0" (zero)](https://www.w3schools.com/cssref/css_units.php) -
#
#     display\
# ```css
# #aligned td {
#         text-align: left;
#         &::before {
#             display: inline-block;
#             content: "";
#             --tens: calc(
#                 round(up, max(1, log(abs(var(--0)), 10)))
#                 + abs(min(0, sign(var(--0))))
#             );
#             width: calc(1ch * (var(--tens-total) - var(--tens)));
#             padding: 0;
#         }
#     }
# }
# ```
#
# add a background grid for visual verification of the decimal alignment.
#
#     display\
# ```css
# #aligned {
#     --w: 2px;
#     position: relative;
#     font-size: 36px;
#     background: linear-gradient(90deg, transparent calc(0.25em - var(--w)), blue var(--w));
#     background-size: 0.25em 100%;
#     background-repeat: repeat-x;
#     tr {
#         background: unset;
#     }
# }
# ```
#
# for each cell value we use the `::before` element to insert a single character width for
# each `--tens` unit. if padding is not removed then we'll end up with extra left whitespace.
# we overlay a visual grid for verification.
#
#     display\
# ```css
# #aligned td {
#     text-align: left;
#     &::before {
#         display: inline-block;
#         content: "";
#         --tens: calc(
#             round(up, max(1, log(abs(var(--0)), 10)))
#             + abs(min(0, sign(var(--0))))
#         );
#         width: calc(1ch * (var(--tens-total) - var(--tens)));
#         padding: 0;
#     }
# }
# ```
#     import nbconvert_a11y.table
#     (df := DataFrame(
#         numpy.random.randn(30, 1)
#     ).pow(9))
#
#
#
#     df.table(id="aligned")
# Out:
# '#aligned {\n    font-family: monospace;\n    --tens-max: calc(\n        round(up, max(1, log(abs(var(--0-max)), 10)))\n        + abs(min(0, sign(var(--0-max))))\n    );\n    --tens-min: calc(\n        round(up, max(1, log(abs(var(--0-min)), 10)))\n        + abs(min(0, sign(var(--0-min))))\n    );\n    --tens-total: calc(max(var(--tens-max), var(--tens-min)));\n'
# '#aligned td {\n        text-align: left;    \n        &::before {\n            display: inline-block;\n            content: "";\n            --tens: calc(\n                round(up, max(1, log(abs(var(--0)), 10)))\n                + abs(min(0, sign(var(--0))))\n            );\n            width: calc(1ch * (var(--tens-total) - var(--tens)));\n            padding: 0;\n        }\n    }\n}\n'
# '#aligned {\n    --w: 2px;\n    position: relative;\n    font-size: 36px;\n    background: linear-gradient(90deg, transparent calc(0.25em - var(--w)), blue var(--w));\n    background-size: 0.25em 100%;\n    background-repeat: repeat-x;\n    tr {\n        background: unset;\n    }\n}\n'
# '#aligned td {\n    text-align: left;    \n    &::before {\n        display: inline-block;\n        content: "";\n        --tens: calc(\n            round(up, max(1, log(abs(var(--0)), 10)))\n            + abs(min(0, sign(var(--0))))\n        );\n        width: calc(1ch * (var(--tens-total) - var(--tens)));\n        padding: 0;\n    }\n}\n'
# Table(object=               0
# 0   3.737674e-06
# 1   6.795158e+02
# 2   8.941315e+01
# 3  -5.908725e+01
# 4  -6.467403e-03
# 5   6.528174e+00
# 6  -1.025344e-11
# 7   2.437958e+01
# 8  -3.769932e+03
# 9   1.109036e-08
# 10 -7.007208e-02
# 11 -1.791210e-09
# 12  2.027085e-02
# 13 -9.012159e-03
# 14  3.206692e-01
# 15 -1.955565e+00
# 16  5.272540e-04
# 17  1.518209e-01
# 18  3.155361e-05
# 19 -5.123122e+00
# 20  1.001564e-01
# 21  1.128472e-04
# 22 -3.398723e-02
# 23  9.232959e-08
# 24  4.040714e-08
# 25 -2.322076e-06
# 26 -2.799038e-06
# 27 -7.867118e-04
# 28  9.108648e-06
# 29  1.195454e-05, options=TableOptions(role=<Role.table: 0>, html=TableOptions.Html(landmark=True, form=False, summary=True), css=TableOptions.Css(cell_var_name='val', number_format='.4f', summary_name=<Naming.ordinal: 1>, naming=<Naming.ordinal: 1>), sorted=True, schema={}, max_rows=60, max_columns=20, axis=<Axis.row: 0>, index=<Presentation.visual: 1>, columns=<Presentation.visual: 1>, include_types=False, ipython_display=True, figcaption=<Position.first: 0>, format='.3f', region_tag='section', fullscreen=True, collapse_form=True, microdata=True, tfoot=<Presentation.visual: 1>, colgroup=True, postprocess=True, css_values=True), schema={}, container=<section aria-labelledby="aligned-figcaption" id="aligned-region"><dialog style="display: contents;"><form method="dialog"><button formmethod="dialog" onclick="event.preventDefault(); event.target.closest(`dialog`).close();">close</button><button onclick="event.preventDefault(); event.target.closest(`dialog`).showModal();">fullscreen</button></form><figure><figcaption id="aligned-figcaption"></figcaption><table aria-labelledby="aligned-figcaption aligned-caption" id="aligned" role="table" style="resize: both;--0-min: -3769.932;--0-max: 679.516;"><caption id="aligned-caption"></caption><colgroup itemprop="index" itemscope=""><col/></colgroup><colgroup itemprop="columns" itemscope=""><col/></colgroup><thead><tr><th scope="col"></th><th>0</th></tr></thead><tbody><tr style="---0: 0;--0: 0; "><th>0</th><td>0.000</td></tr><tr style="---0: 1;--0: 679.5158; "><th>1</th><td>679.516</td></tr><tr style="---0: 2;--0: 89.4131; "><th>2</th><td>89.413</td></tr><tr style="---0: 3;--0: -59.0872; "><th>3</th><td>-59.087</td></tr><tr style="---0: 4;--0: -0.0065; "><th>4</th><td>-0.006</td></tr><tr style="---0: 5;--0: 6.5282; "><th>5</th><td>6.528</td></tr><tr style="---0: 6;--0: -1e-06; "><th>6</th><td>-0.000</td></tr><tr style="---0: 7;--0: 24.3796; "><th>7</th><td>24.380</td></tr><tr style="---0: 8;--0: -3769.9317; "><th>8</th><td>-3769.932</td></tr><tr style="---0: 9;--0: 0; "><th>9</th><td>0.000</td></tr><tr style="---0: 10;--0: -0.0701; "><th>10</th><td>-0.070</td></tr><tr style="---0: 11;--0: -1e-06; "><th>11</th><td>-0.000</td></tr><tr style="---0: 12;--0: .0203; "><th>12</th><td>0.020</td></tr><tr style="---0: 13;--0: -0.009; "><th>13</th><td>-0.009</td></tr><tr style="---0: 14;--0: .3207; "><th>14</th><td>0.321</td></tr><tr style="---0: 15;--0: -1.9556; "><th>15</th><td>-1.956</td></tr><tr style="---0: 16;--0: .0005; "><th>16</th><td>0.001</td></tr><tr style="---0: 17;--0: .1518; "><th>17</th><td>0.152</td></tr><tr style="---0: 18;--0: 0; "><th>18</th><td>0.000</td></tr><tr style="---0: 19;--0: -5.1231; "><th>19</th><td>-5.123</td></tr><tr style="---0: 20;--0: .1002; "><th>20</th><td>0.100</td></tr><tr style="---0: 21;--0: .0001; "><th>21</th><td>0.000</td></tr><tr style="---0: 22;--0: -0.034; "><th>22</th><td>-0.034</td></tr><tr style="---0: 23;--0: 0; "><th>23</th><td>0.000</td></tr><tr style="---0: 24;--0: 0; "><th>24</th><td>0.000</td></tr><tr style="---0: 25;--0: -1e-06; "><th>25</th><td>-0.000</td></tr><tr style="---0: 26;--0: -1e-06; "><th>26</th><td>-0.000</td></tr><tr style="---0: 27;--0: -0.0008; "><th>27</th><td>-0.001</td></tr><tr style="---0: 28;--0: 0; "><th>28</th><td>0.000</td></tr><tr style="---0: 29;--0: 0; "><th>29</th><td>0.000</td></tr></tbody><tfoot><tr style="--0: -3769.9317; "><th scope="row">min</th><td>-3769.932</td></tr><tr style="--0: 679.5158; "><th scope="row">max</th><td>679.516</td></tr></tfoot></table></figure><dialog style="display: contents;"><form aria-describedby="aligned-desc" aria-labelledby="aligned-figcaption" name="aligned"><details><summary>controls</summary><button formmethod="dialog" onclick="event.preventDefault(); event.target.closest(`dialog`).close();">close</button><button onclick="event.preventDefault(); event.target.closest(`dialog`).showModal();">fullscreen</button><p id="aligned-desc"></p><button type="submit">submit</button></details></ ...
#  tr {--0-ratio: calc((var(--0) - var(--0-min)) / var(--0-diff));
# }}</style></section>, table=<table aria-labelledby="aligned-figcaption aligned-caption" id="aligned" role="table" style="resize: both;--0-min: -3769.932;--0-max: 679.516;"><caption id="aligned-caption"></caption><colgroup itemprop="index" itemscope=""><col/></colgroup><colgroup itemprop="columns" itemscope=""><col/></colgroup><thead><tr><th scope="col"></th><th>0</th></tr></thead><tbody><tr style="---0: 0;--0: 0; "><th>0</th><td>0.000</td></tr><tr style="---0: 1;--0: 679.5158; "><th>1</th><td>679.516</td></tr><tr style="---0: 2;--0: 89.4131; "><th>2</th><td>89.413</td></tr><tr style="---0: 3;--0: -59.0872; "><th>3</th><td>-59.087</td></tr><tr style="---0: 4;--0: -0.0065; "><th>4</th><td>-0.006</td></tr><tr style="---0: 5;--0: 6.5282; "><th>5</th><td>6.528</td></tr><tr style="---0: 6;--0: -1e-06; "><th>6</th><td>-0.000</td></tr><tr style="---0: 7;--0: 24.3796; "><th>7</th><td>24.380</td></tr><tr style="---0: 8;--0: -3769.9317; "><th>8</th><td>-3769.932</td></tr><tr style="---0: 9;--0: 0; "><th>9</th><td>0.000</td></tr><tr style="---0: 10;--0: -0.0701; "><th>10</th><td>-0.070</td></tr><tr style="---0: 11;--0: -1e-06; "><th>11</th><td>-0.000</td></tr><tr style="---0: 12;--0: .0203; "><th>12</th><td>0.020</td></tr><tr style="---0: 13;--0: -0.009; "><th>13</th><td>-0.009</td></tr><tr style="---0: 14;--0: .3207; "><th>14</th><td>0.321</td></tr><tr style="---0: 15;--0: -1.9556; "><th>15</th><td>-1.956</td></tr><tr style="---0: 16;--0: .0005; "><th>16</th><td>0.001</td></tr><tr style="---0: 17;--0: .1518; "><th>17</th><td>0.152</td></tr><tr style="---0: 18;--0: 0; "><th>18</th><td>0.000</td></tr><tr style="---0: 19;--0: -5.1231; "><th>19</th><td>-5.123</td></tr><tr style="---0: 20;--0: .1002; "><th>20</th><td>0.100</td></tr><tr style="---0: 21;--0: .0001; "><th>21</th><td>0.000</td></tr><tr style="---0: 22;--0: -0.034; "><th>22</th><td>-0.034</td></tr><tr style="---0: 23;--0: 0; "><th>23</th><td>0.000</td></tr><tr style="---0: 24;--0: 0; "><th>24</th><td>0.000</td></tr><tr style="---0: 25;--0: -1e-06; "><th>25</th><td>-0.000</td></tr><tr style="---0: 26;--0: -1e-06; "><th>26</th><td>-0.000</td></tr><tr style="---0: 27;--0: -0.0008; "><th>27</th><td>-0.001</td></tr><tr style="---0: 28;--0: 0; "><th>28</th><td>0.000</td></tr><tr style="---0: 29;--0: 0; "><th>29</th><td>0.000</td></tr></tbody><tfoot><tr style="--0: -3769.9317; "><th scope="row">min</th><td>-3769.932</td></tr><tr style="--0: 679.5158; "><th scope="row">max</th><td>679.516</td></tr></tfoot></table>, stats=j              0
# min -3769.931672
# max   679.515789, id='aligned', kind=<COMPLEX_TABLE.simple: False>, cranges=(RangeIndex(start=0, stop=1, step=1, name='j'),), rranges=(RangeIndex(start=0, stop=30, step=1, name='i'),))
# <p>our approach is to calculate the order of magnitude of our values and their sign on a monospace font.
# we only need the maximum number of digits and signs before the decimal;
# we'll refer to these values with the prefix <code>--tens</code></p>
# <pre><code>display\
# </code></pre>
# <pre><code class="css"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>#<span style="color: #0000FF; font-weight: bold">aligned</span><span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">font-family</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">monospace</span>;
# <span style="color: #bbbbbb">    </span><span style="color: #19177C">--tens-max</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000">calc</span>(
# <span style="color: #bbbbbb">        </span><span style="color: #008000; font-weight: bold">round</span><span style="border: 1px solid #FF0000">(</span>up,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">max</span>(<span style="color: #666666">1</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">log</span>(<span style="color: #0000FF">abs</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span><span style="color: #19177C">-max</span>)),<span style="color: #bbbbbb"> </span><span style="color: #666666">10</span>)))
# <span style="color: #bbbbbb">        </span><span style="color: #666666">+</span><span style="color: #bbbbbb"> </span><span style="color: #0000FF">abs</span>(<span style="color: #0000FF">min</span>(<span style="color: #666666">0</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">sign</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span><span style="color: #19177C">-max</span>))))
# <span style="color: #bbbbbb">    </span>);
# <span style="color: #bbbbbb">    </span><span style="color: #19177C">--tens-min</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000">calc</span>(
# <span style="color: #bbbbbb">        </span><span style="color: #008000; font-weight: bold">round</span><span style="border: 1px solid #FF0000">(</span>up,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">max</span>(<span style="color: #666666">1</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">log</span>(<span style="color: #0000FF">abs</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span><span style="color: #19177C">-min</span>)),<span style="color: #bbbbbb"> </span><span style="color: #666666">10</span>)))
# <span style="color: #bbbbbb">        </span><span style="color: #666666">+</span><span style="color: #bbbbbb"> </span><span style="color: #0000FF">abs</span>(<span style="color: #0000FF">min</span>(<span style="color: #666666">0</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">sign</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span><span style="color: #19177C">-min</span>))))
# <span style="color: #bbbbbb">    </span>);
# <span style="color: #bbbbbb">    </span><span style="color: #19177C">--tens-total</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000">calc</span>(<span style="color: #0000FF">max</span>(<span style="color: #0000FF">var</span>(<span style="color: #19177C">--tens-max</span>),<span style="color: #bbbbbb"> </span><span style="color: #0000FF">var</span>(<span style="color: #19177C">--tens-min</span>)));
# </pre></div>
# </code></pre>
# <p>insert a pseudo-element in each table cell that using <code>1ch</code> spaces -
# <a href="https://www.w3schools.com/cssref/css_units.php">Relative to the width of the &quot;0&quot; (zero)</a> -</p>
# <pre><code>display\
# </code></pre>
# <pre><code class="css"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>#<span style="color: #0000FF; font-weight: bold">aligned</span><span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">td</span><span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">        </span><span style="color: #008000; font-weight: bold">text-align</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">left</span>;<span style="color: #bbbbbb">    </span>
# <span style="color: #bbbbbb">        </span><span style="border: 1px solid #FF0000">&amp;::before</span><span style="color: #bbbbbb"> </span><span style="border: 1px solid #FF0000">{</span>
# <span style="color: #bbbbbb">            </span><span style="color: #008000; font-weight: bold">display</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">inline-block</span>;
# <span style="color: #bbbbbb">            </span><span style="color: #008000; font-weight: bold">content</span>:<span style="color: #bbbbbb"> </span><span style="color: #BA2121">&quot;&quot;</span>;
# <span style="color: #bbbbbb">            </span><span style="color: #19177C">--tens</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000">calc</span>(
# <span style="color: #bbbbbb">                </span><span style="color: #008000; font-weight: bold">round</span><span style="border: 1px solid #FF0000">(</span>up,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">max</span>(<span style="color: #666666">1</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">log</span>(<span style="color: #0000FF">abs</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span>)),<span style="color: #bbbbbb"> </span><span style="color: #666666">10</span>)))
# <span style="color: #bbbbbb">                </span><span style="color: #666666">+</span><span style="color: #bbbbbb"> </span><span style="color: #0000FF">abs</span>(<span style="color: #0000FF">min</span>(<span style="color: #666666">0</span>,<span style="color: #bbbbbb"> </span><span style="color: #0000FF">sign</span>(<span style="color: #0000FF">var</span>(<span style="color: #666666">--0</span>))))
# <span style="color: #bbbbbb">            </span>);
# <span style="color: #bbbbbb">            </span><span style="color: #008000; font-weight: bold">width</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000">calc</span>(<span style="color: #666666">1</span><span style="color: #B00040">ch</span><span style="color: #bbbbbb"> </span><span style="color: #666666">*</span><span style="color: #bbbbbb"> </span><span style="border: 1px solid #FF0000">(</span><span style="color: #0000FF">var</span>(<span style="color: #19177C">--tens-total</span>)<span style="color: #bbbbbb"> </span><span style="color: #666666">-</span><span style="color: #bbbbbb"> </span><span style="color: #0000FF">var</span>(<span style="color: #19177C">--tens</span>)));
# <span style="color: #bbbbbb">            </span><span style="color: #008000; font-weight: bold">padding</span>:<span style="color: #bbbbbb"> </span><span style="color: #666666">0</span>;
# <span style="color: #bbbbbb">        </span>}
# <span style="color: #bbbbbb">    </span><span style="border: 1px solid #FF0000">}</span>
# <span style="border: 1px solid #FF0000">}</span>
# </pre></div>
# </code></pre>
# <p>add a background grid for visual verification of the decimal alignment.</p>
# <pre><code>display\
# </code></pre>
# <pre><code class="css"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>#<span style="color: #0000FF; font-weight: bold">aligned</span><span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">    </span><span style="color: #19177C">--w</span>:<span style="color: #bbbbbb"> </span><span style="color: #666666">2</span><span style="color: #B00040">px</span>;
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">position</span>:<span style="color: #bbbbbb"> </span><span styl
