# %% [markdown]
# # differentiating strings in dataframes for nonvisual representations
#
# this started because our accessible tables need to be smarter about strings and what they mean.

# %%
# %%
#     import nbconvert_a11y.table
#     table = DataFrame([[
# ```css
# .jp-Cell {background: green;}
# ```
#     ,
# ```css
# .jp-Cell {border: solid 3px;}
# ```
#     ]]).T.table(nbconvert_a11y.table.TableOptions(
#         ipython_display=False, schema= (schema :=
# ```toml
# title = "a dataframe containing css strings"
# [properties.0]
# contentMediaType = "text/css"
# ```
#     )))
#     schema["$comment"] =\
# we need to be able differentiate strings from a table to reason with their nonvisual and visual properties.
# for example, some strings may be valid css and others may not be valid.
# do we need to access the string on `::before` and `::after` pseudoelements?
#
# futher, i realized that caption and description from the schema should be used in the presentation.
#
#     display(table, schema)
# Out:
# Table(object=                                 0
# 0  .jp-Cell {background: green;}\n
# 1  .jp-Cell {border: solid 3px;}\n, options=TableOptions(role=<Role.table: 0>, html=TableOptions.Html(landmark=True, form=False, summary=True), css=TableOptions.Css(cell_var_name='val', number_format='.4f', summary_name=<Naming.ordinal: 1>, naming=<Naming.ordinal: 1>), sorted=True, schema={'title': 'a dataframe containing css strings', 'properties': {'0': {'contentMediaType': 'text/css'}}, '$comment': 'we need to be able differentiate strings from a table to reason with their nonvisual and visual properties.\nfor example, some strings may be valid css and others may not be valid.\ndo we need to access the string on `::before` and `::after` pseudoelements?\n\nfuther, i realized that caption and description from the schema should be used in the presentation.'}, max_rows=60, max_columns=20, axis=<Axis.row: 0>, index=<Presentation.visual: 1>, columns=<Presentation.visual: 1>, tfoot=True, include_types=False, ipython_display=False, figcaption=<Position.first: 0>, format='.3f', region_tag='section'), html=<section aria-labelledby="a9d209550-7862-4969-9ad8-fc06738e258d-figcaption"><figure><figcaption id="a9d209550-7862-4969-9ad8-fc06738e258d-figcaption"></figcaption><table aria-colcount="2" aria-rowcount="6" id="a9d209550-7862-4969-9ad8-fc06738e258d" role="table" style="---0-min: 0; ---0-max: 1; ---0-diff: 1;"><caption id="a9d209550-7862-4969-9ad8-fc06738e258d-caption">pandas dataframe with 2 rows, 1 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row" style='---0: &lt;th aria-colindex="1" aria-rowindex="1" aria-sort="ascending" role="colheader" style=""&gt;None&lt;/th&gt;;  ---1: &lt;th aria-colindex="2" aria-rowindex="1" aria-sort="ascending" role="colheader" style=""&gt;0&lt;/th&gt;; '><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="colheader" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" aria-sort="ascending" role="colheader">0</th></tr><tr role="row"><td aria-colindex="2" aria-rowindex="2" role="cell"></td></tr><tr role="row" style='---1: &lt;th aria-colindex="1" aria-rowindex="3" style=""&gt;type&lt;/th&gt;; '><th aria-colindex="1" aria-rowindex="3">type</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style='---0: 0; ---1: &lt;th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="rowheader" scope="row" style="---0: 0; "&gt;0&lt;/th&gt;; '><th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="rowheader" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">.jp-Cell {background: green;}
# </td></tr><tr role="row" style='---0: 1; ---1: &lt;th aria-colindex="1" aria-rowindex="3" aria-sort="descending" role="rowheader" scope="row" style="---0: 1; "&gt;1&lt;/th&gt;; '><th aria-colindex="1" aria-rowindex="3" aria-sort="descending" role="rowheader" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">.jp-Cell {border: solid 3px;}
# </td></tr></tbody><tfoot role="rowgroup"><tr role="row" style='---1: &lt;th aria-colindex="1" aria-rowindex="4" style=""&gt;min&lt;/th&gt;; '><th aria-colindex="1" aria-rowindex="4">min</th><td aria-colindex="2" aria-rowindex="4" role="cell">.jp-Cell {background: green;}
# </td></tr><tr role="row" style='---1: &lt;th aria-colindex="1" aria-rowindex="5" style=""&gt;max&lt;/th&gt;; '><th aria-colindex="1" aria-rowindex="5">max</th><td aria-colindex="2" aria-rowindex="5" role="cell">.jp-Cell {border: solid 3px;}
# </td></tr><tr role="row" style='---1: &lt;th aria-colindex="1" aria-rowindex="6" style=""&gt;diff&lt;/th&gt;;  --0: nan; '><th aria-colindex="1" aria-rowindex="6">diff</th><td aria-colindex="2" aria-rowindex="6" role="cell">nan</td></tr></tfoot></table></figure><form aria-labelledby="a9d209550-7862-4969-9ad8-fc06738e258d-figcaption" name="a9d209550-7862-4969-9ad8-fc06738e258d"><button aria-controls="None-schema" onclick='event.preventDefault(); document.getElementById(this.getAttribute("aria-controls")).showModal()'>more information</button></form><style>#None tr {  }</style><script>function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }</script><script>document.querySelectorAll("#a9d209550-7862-4969-9ad8-fc06738e258d [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script><dialog id="None-schema"><form><button formmethod="dialog">close</button><h1>schema</h1><dt><samp class="s2" itemscope itemtype="builtins:str">title</samp></dt><dd><samp class="s2" itemscope itemtype="builtins:str">a dataframe containing css strings</samp></dd><dt><samp class="s2" itemscope itemtype="builtins:str">properties</samp></dt><dd><dl id="126498738876096" itemscope itemtype="builtins:dict"><dt><samp class="s2" itemscope itemtype="builtins:str">0</samp></dt><dd><dl id="126498738876160" itemscope itemtype="builtins:dict"><dt><samp class="s2" itemscope itemtype="builtins:str">contentMediaType</samp></dt><dd><samp class="s2" itemscope itemtype="builtins:str">text/css</samp></dd></dl></dd></dl></dd></form></dialog></section>, id='a9d209550-7862-4969-9ad8-fc06738e258d')
# {'title': 'a dataframe containing css strings',
#  'properties': {'0': {'contentMediaType': 'text/css'}},
#  '$comment': 'we need to be able differentiate strings from a table to reason with their nonvisual and visual properties.\nfor example, some strings may be valid css and others may not be valid.\ndo we need to access the string on `::before` and `::after` pseudoelements?\n\nfuther, i realized that caption and description from the schema should be used in the presentation.'}
# <pre><code>import nbconvert_a11y.table
# table = DataFrame([[
# </code></pre>
# <pre><code class="css"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>.<span style="color: #0000FF; font-weight: bold">jp-Cell</span><span style="color: #bbbbbb"> </span>{<span style="color: #008000; font-weight: bold">background</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">green</span>;}
# </pre></div>
# </code></pre>
# <pre><code>,
# </code></pre>
# <pre><code class="css"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>.<span style="color: #0000FF; font-weight: bold">jp-Cell</span><span style="color: #bbbbbb"> </span>{<span style="color: #008000; font-weight: bold">border</span>:<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">solid</span><span style="color: #bbbbbb"> </span><span style="color: #666666">3</span><span style="color: #B00040">px</span>;}
# </pre></div>
# </code></pre>
# <pre><code>]]).T.table(nbconvert_a11y.table.TableOptions(
#     ipython_display=False, schema= (schema :=
# </code></pre>
# <pre><code class="toml"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>title<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span><span style="color: #BA2121">&quot;a dataframe containing css strings&quot;</span>
# <span style="color: #008000; font-weight: bold">[properties.0]</span>
# contentMediaType<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span><span style="color: #BA2121">&quot;text/css&quot;</span>
# </pre></div>
# </code></pre>
# <pre><code>)))
# schema[&quot;$comment&quot;] =\
# </code></pre>
# <p>we need to be able differentiate strings from a table to reason with their nonvisual and visual properties.
# for example, some strings may be valid css and others may not be valid.
# do we need to access the string on <code>::before</code> and <code>::after</code> pseudoelements?</p>
# <p>futher, i realized that caption and description from the schema should be used in the presentation.</p>
# <pre><code>display(table, schema)</code></pre>

# %% [markdown]
# ## marginalia
#
# i really like this idea because the one cell demonstrates several languages because used in code together.
