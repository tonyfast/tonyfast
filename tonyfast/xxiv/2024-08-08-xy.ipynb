# %% [markdown]
# # table to xy plot
#
# [demo](#demo)

# %%
# %%
#
#     import nbconvert_a11y.table
#     DataFrame(numpy.random.randn(20, 2), columns=list("xy")).table(id="xy", caption="randomly generated data that transforms into a 2d plot.").style(
# ```css
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
# ```
#     ).checkbox({
#         ("activate baseline plot styling", True):
# ```css
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     border-left: solid blue;
#     border-right: solid blue;
#     border-top: solid red;
#     border-bottom: solid red;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 translateY(.5rem)
#                 ;
#         }
#     }
# }
# ```
#     , ("distribute markers in x", True):
# ```css
# --X: 1;
# ```
#     , ("distribute markers in y", True):
# ```css
# --Y: 1;
# ```
#     }).radiogroup({
#     ("axis to the left", True) :
# ```css
# ```
#
#     , "center data":
# ```css
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
# ```
#     , "axis to the right":
# ```css
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
# ```
#
#     }, name="origins")
# Out:
# Table(object=           x         y
# 0  -0.508149  1.369576
# 1  -1.277262 -0.300643
# 2  -0.676536 -0.576645
# 3   0.549957  1.401704
# 4  -0.982049 -3.243512
# 5  -0.681769 -0.098045
# 6   1.818692 -1.055545
# 7   1.419161 -0.047559
# 8   0.028461  1.307188
# 9  -0.041482 -1.045784
# 10  0.259949  0.512882
# 11  1.283454  0.428539
# 12  0.840896  0.874080
# 13  1.647614 -0.159335
# 14 -0.281835  0.552976
# 15 -1.406003  0.845986
# 16  0.300258 -0.774587
# 17 -0.594980 -0.670345
# 18  2.411060 -0.695250
# 19 -0.462635 -0.999179, options=None, html=<section aria-labelledby="xy-figcaption"><figure><table aria-colcount="3" aria-rowcount="24" id="xy" role="table" style="---0-min: 0; ---0-max: 19; ---0-diff: 19; ---0-magnitude: 2; --0-min: -1.4060; --0-max: 2.4111; --0-diff: 3.8171; --1-min: -3.2435; --1-max: 1.4017; --1-diff: 4.6452;"><caption id="xy-caption">pandas dataframe with 20 rows, 2 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row"><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="cell" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" role="cell">'x'</th><th aria-colindex="3" aria-rowindex="1" role="cell">'y'</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style="---0: 0;  --0: -0.5081;  --1: 1.3696; "><th aria-colindex="1" aria-rowindex="2" aria-sort="ascending" role="cell" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">-0.508</td><td aria-colindex="3" aria-rowindex="2" role="cell">1.370</td></tr><tr role="row" style="---0: 1;  --0: -1.2773;  --1: -0.3006; "><th aria-colindex="1" aria-rowindex="3" aria-sort="ascending" role="cell" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">-1.277</td><td aria-colindex="3" aria-rowindex="3" role="cell">-0.301</td></tr><tr role="row" style="---0: 2;  --0: -0.6765;  --1: -0.5766; "><th aria-colindex="1" aria-rowindex="4" aria-sort="ascending" role="cell" scope="row">2</th><td aria-colindex="2" aria-rowindex="4" role="cell">-0.677</td><td aria-colindex="3" aria-rowindex="4" role="cell">-0.577</td></tr><tr role="row" style="---0: 3;  --0: 0.5500;  --1: 1.4017; "><th aria-colindex="1" aria-rowindex="5" aria-sort="ascending" role="cell" scope="row">3</th><td aria-colindex="2" aria-rowindex="5" role="cell">0.550</td><td aria-colindex="3" aria-rowindex="5" role="cell">1.402</td></tr><tr role="row" style="---0: 4;  --0: -0.9820;  --1: -3.2435; "><th aria-colindex="1" aria-rowindex="6" aria-sort="descending" role="cell" scope="row">4</th><td aria-colindex="2" aria-rowindex="6" role="cell">-0.982</td><td aria-colindex="3" aria-rowindex="6" role="cell">-3.244</td></tr><tr role="row" style="---0: 5;  --0: -0.6818;  --1: -0.0980; "><th aria-colindex="1" aria-rowindex="7" aria-sort="ascending" role="cell" scope="row">5</th><td aria-colindex="2" aria-rowindex="7" role="cell">-0.682</td><td aria-colindex="3" aria-rowindex="7" role="cell">-0.098</td></tr><tr role="row" style="---0: 6;  --0: 1.8187;  --1: -1.0555; "><th aria-colindex="1" aria-rowindex="8" aria-sort="descending" role="cell" scope="row">6</th><td aria-colindex="2" aria-rowindex="8" role="cell">1.819</td><td aria-colindex="3" aria-rowindex="8" role="cell">-1.056</td></tr><tr role="row" style="---0: 7;  --0: 1.4192;  --1: -0.0476; "><th aria-colindex="1" aria-rowindex="9" aria-sort="descending" role="cell" scope="row">7</th><td aria-colindex="2" aria-rowindex="9" role="cell">1.419</td><td aria-colindex="3" aria-rowindex="9" role="cell">-0.048</td></tr><tr role="row" style="---0: 8;  --0: 0.0285;  --1: 1.3072; "><th aria-colindex="1" aria-rowindex="10" aria-sort="ascending" role="cell" scope="row">8</th><td aria-colindex="2" aria-rowindex="10" role="cell">0.028</td><td aria-colindex="3" aria-rowindex="10" role="cell">1.307</td></tr><tr role="row" style="---0: 9;  --0: -0.0415;  --1: -1.0458; "><th aria-colindex="1" aria-rowindex="11" aria-sort="descending" role="cell" scope="row">9</th><td aria-colindex="2" aria-rowindex="11" role="cell">-0.041</td><td aria-colindex="3" aria-rowindex="11" role="cell">-1.046</td></tr><tr role="row" style="---0: 10;  --0: 0.2599;  --1: 0.5129; "><th aria-colindex="1" aria-rowindex="12" aria-sort="ascending" role="cell" scope="row">10</th><td aria-colindex="2" aria-rowindex="12" role="cell">0.260</td><td aria-colindex="3" aria-rowindex="12" role="cell">0.513</td></tr><tr role="row" style="---0: 11;  --0: 1.2835;  --1: 0.4285;  ...
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>activate baseline plot styling</label><style id="xy-options-style-0" media="all">#xy {
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     border-left: solid blue;
#     border-right: solid blue;
#     border-top: solid red;
#     border-bottom: solid red;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 translateY(.5rem)
#                 ;
#         }
#     }
# }
#
# }</style></li><li><label><input aria-controls="xy-options-style-1" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in x</label><style id="xy-options-style-1" media="all">#xy {
# --X: 1;
#
# }</style></li><li><label><input aria-controls="xy-options-style-2" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in y</label><style id="xy-options-style-2" media="all">#xy {
# --Y: 1;
#
# }</style></li></ul><ul role="none"><li><label><input aria-controls="xy-origins-style-0" checked="" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the left</label><style id="xy-origins-style-0" media="all">#xy {
#
# }</style></li><li><label><input aria-controls="xy-origins-style-1" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>center data</label><style id="xy-origins-style-1" media="none">#xy {
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
#
# }</style></li><li><label><input aria-controls="xy-origins-style-2" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the right</label><style id="xy-origins-style-2" media="none">#xy {
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
#
# }</style></li></ul></form><style id="xy-style">#xy tr { --x: var(--0);
# --y: var(--1);
#  }#xy {
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
#
# }</style><script id="xy-script">function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }document.querySelectorAll("#xy [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script></section>, id='xy')

# %%
# %%
#
# ```css
# [href="#demo"] {
#     background: -moz-element(#xy);
#     background-size: contain;
#     font-size: 10rem;
# }
# ```
# Out:
# '[href="#demo"] {\n    background: -moz-element(#xy);\n    background-size: contain;\n    font-size: 10rem;\n}\n'
