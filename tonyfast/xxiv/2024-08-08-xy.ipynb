# %% [markdown]
# # table to xy plot
#
# [demo](#demo)

# %%
# %%
#
#     import nbconvert_a11y.table
#     DataFrame(numpy.random.randn(20, 2), columns=list("xy")).table(id="xy", caption="randomly generated data that transforms into a 2d plot.").style(
# ```css
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
# ```
#     ).checkbox({
#         ("activate baseline plot styling", True):
# ```css
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 ;
#         }
#     }
# }
# ```
#     , ("distribute markers in x", True):
# ```css
# --X: 1;
# ```
#     , ("distribute markers in y", True):
# ```css
# --Y: 1;
# ```
#     }).radiogroup({
#     ("axis to the left", True) :
# ```css
# ```
#
#     , "center data":
# ```css
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
# ```
#     , "axis to the right":
# ```css
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
# ```
#
#     }, name="origins")
# Out:
# Table(object=           x         y
# 0   0.016998 -0.797462
# 1  -1.605049  0.452245
# 2   0.860911 -0.129807
# 3   0.628412  0.132487
# 4   1.589932  0.559122
# 5   0.037694 -0.140970
# 6   0.299569 -0.362086
# 7   0.262188  0.843621
# 8  -1.962288  1.321254
# 9   0.059035 -2.042588
# 10 -0.169847 -1.163053
# 11  1.578711 -1.121954
# 12  1.551800 -0.715399
# 13 -0.542623  1.576226
# 14  0.482962  1.078244
# 15 -1.766957  1.534997
# 16 -0.819525  1.575873
# 17 -0.105414  0.195160
# 18  0.450831 -0.578773
# 19  0.614370 -0.398298, options=None, html=<section aria-labelledby="xy-figcaption"><figure><table aria-colcount="3" aria-rowcount="24" id="xy" role="table" style="---0-min: 0; ---0-max: 19; ---0-diff: 19; ---0-magnitude: 2; --0-min: -1.9623; --0-max: 1.5899; --0-diff: 3.5522; --1-min: -2.0426; --1-max: 1.5762; --1-diff: 3.6188;"><caption id="xy-caption">pandas dataframe with 20 rows, 2 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row"><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="cell" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" role="cell">'x'</th><th aria-colindex="3" aria-rowindex="1" role="cell">'y'</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style="---0: 0;  --0: 0.0170;  --1: -0.7975; "><th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="cell" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">0.017</td><td aria-colindex="3" aria-rowindex="2" role="cell">-0.797</td></tr><tr role="row" style="---0: 1;  --0: -1.6050;  --1: 0.4522; "><th aria-colindex="1" aria-rowindex="3" aria-sort="ascending" role="cell" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">-1.605</td><td aria-colindex="3" aria-rowindex="3" role="cell">0.452</td></tr><tr role="row" style="---0: 2;  --0: 0.8609;  --1: -0.1298; "><th aria-colindex="1" aria-rowindex="4" aria-sort="descending" role="cell" scope="row">2</th><td aria-colindex="2" aria-rowindex="4" role="cell">0.861</td><td aria-colindex="3" aria-rowindex="4" role="cell">-0.130</td></tr><tr role="row" style="---0: 3;  --0: 0.6284;  --1: 0.1325; "><th aria-colindex="1" aria-rowindex="5" aria-sort="descending" role="cell" scope="row">3</th><td aria-colindex="2" aria-rowindex="5" role="cell">0.628</td><td aria-colindex="3" aria-rowindex="5" role="cell">0.132</td></tr><tr role="row" style="---0: 4;  --0: 1.5899;  --1: 0.5591; "><th aria-colindex="1" aria-rowindex="6" aria-sort="descending" role="cell" scope="row">4</th><td aria-colindex="2" aria-rowindex="6" role="cell">1.590</td><td aria-colindex="3" aria-rowindex="6" role="cell">0.559</td></tr><tr role="row" style="---0: 5;  --0: 0.0377;  --1: -0.1410; "><th aria-colindex="1" aria-rowindex="7" aria-sort="descending" role="cell" scope="row">5</th><td aria-colindex="2" aria-rowindex="7" role="cell">0.038</td><td aria-colindex="3" aria-rowindex="7" role="cell">-0.141</td></tr><tr role="row" style="---0: 6;  --0: 0.2996;  --1: -0.3621; "><th aria-colindex="1" aria-rowindex="8" aria-sort="descending" role="cell" scope="row">6</th><td aria-colindex="2" aria-rowindex="8" role="cell">0.300</td><td aria-colindex="3" aria-rowindex="8" role="cell">-0.362</td></tr><tr role="row" style="---0: 7;  --0: 0.2622;  --1: 0.8436; "><th aria-colindex="1" aria-rowindex="9" aria-sort="ascending" role="cell" scope="row">7</th><td aria-colindex="2" aria-rowindex="9" role="cell">0.262</td><td aria-colindex="3" aria-rowindex="9" role="cell">0.844</td></tr><tr role="row" style="---0: 8;  --0: -1.9623;  --1: 1.3213; "><th aria-colindex="1" aria-rowindex="10" aria-sort="ascending" role="cell" scope="row">8</th><td aria-colindex="2" aria-rowindex="10" role="cell">-1.962</td><td aria-colindex="3" aria-rowindex="10" role="cell">1.321</td></tr><tr role="row" style="---0: 9;  --0: 0.0590;  --1: -2.0426; "><th aria-colindex="1" aria-rowindex="11" aria-sort="descending" role="cell" scope="row">9</th><td aria-colindex="2" aria-rowindex="11" role="cell">0.059</td><td aria-colindex="3" aria-rowindex="11" role="cell">-2.043</td></tr><tr role="row" style="---0: 10;  --0: -0.1698;  --1: -1.1631; "><th aria-colindex="1" aria-rowindex="12" aria-sort="descending" role="cell" scope="row">10</th><td aria-colindex="2" aria-rowindex="12" role="cell">-0.170</td><td aria-colindex="3" aria-rowindex="12" role="cell">-1.163</td></tr><tr role="row" style="---0: 11;  --0: 1.5787;  --1: -1.1220; ">< ...
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>activate baseline plot styling</label><style id="xy-options-style-0" media="all">#xy {
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 ;
#         }
#     }
# }
#
# }</style></li><li><label><input aria-controls="xy-options-style-1" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in x</label><style id="xy-options-style-1" media="all">#xy {
# --X: 1;
#
# }</style></li><li><label><input aria-controls="xy-options-style-2" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in y</label><style id="xy-options-style-2" media="all">#xy {
# --Y: 1;
#
# }</style></li></ul><ul role="none"><li><label><input aria-controls="xy-origins-style-0" checked="" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the left</label><style id="xy-origins-style-0" media="all">#xy {
#
# }</style></li><li><label><input aria-controls="xy-origins-style-1" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>center data</label><style id="xy-origins-style-1" media="none">#xy {
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
#
# }</style></li><li><label><input aria-controls="xy-origins-style-2" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the right</label><style id="xy-origins-style-2" media="none">#xy {
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
#
# }</style></li></ul></form><style id="xy-style">#xy tr { --x: var(--0);
# --y: var(--1);
#  }#xy {
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
#
# }</style><script id="xy-script">function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }document.querySelectorAll("#xy [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script></section>, id='xy')

# %%
# %%
#
# ```css
# [href="#demo"] {
#     background: -moz-element(#xy);
#     background-size: contain;
#     font-size: 10rem;
# }
# ```
# Out:
# '[href="#demo"] {\n    background: -moz-element(#xy);\n    background-size: contain;\n    font-size: 10rem;\n}\n'
