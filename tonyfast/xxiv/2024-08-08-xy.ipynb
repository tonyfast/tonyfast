# %% [markdown]
# # table to xy plot
#
# [demo](#demo)

# %%
# %%
#
#     import nbconvert_a11y.table
#     DataFrame(numpy.random.randn(20, 2), columns=list("xy")).table(id="xy", caption="randomly generated data that transforms into a 2d plot.").style(
# ```css
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
# ```
#     ).checkbox({"activate baseline plot styling":
# ```css
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     tr {
#         background: unset;
#         transition: 5s all linear;
#         display: flex; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#     }
# }
# ```
#     , "distribute markers in x":
# ```css
# --X: 1;
# ```
#     , "distribute markers in y":
# ```css
# --Y: 1;
# ```
#     })
# Out:
# Table(object=           x         y
# 0   0.914880 -0.864809
# 1  -1.092851  0.238604
# 2   0.019545 -1.115176
# 3  -1.177295  0.830868
# 4   0.129660 -0.931366
# 5  -0.810092  0.670501
# 6   1.882264  0.000145
# 7   0.670001 -0.220479
# 8  -1.345601  0.864125
# 9  -0.745892 -0.482560
# 10 -0.770119  0.362038
# 11  0.346458  0.222695
# 12  0.579333  0.116825
# 13  0.857255  0.243731
# 14 -0.037362  0.099839
# 15  1.616708  0.275891
# 16 -0.815426  1.767647
# 17  1.003152  0.368401
# 18  0.532427 -0.176976
# 19 -0.364296 -0.593484, options=None, html=<section aria-labelledby="xy-figcaption"><figure><table aria-colcount="3" aria-rowcount="24" id="xy" role="table" style="---0-min: 0; ---0-max: 19; ---0-diff: 19; ---0-magnitude: 2; --0-min: -1.3456; --0-max: 1.8823; --0-diff: 3.2279; --1-min: -1.1152; --1-max: 1.7676; --1-diff: 2.8828;"><caption id="xy-caption">pandas dataframe with 20 rows, 2 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row"><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="cell" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" role="cell">'x'</th><th aria-colindex="3" aria-rowindex="1" role="cell">'y'</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style="---0: 0;  --0: 0.9149;  --1: -0.8648; "><th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="cell" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">0.915</td><td aria-colindex="3" aria-rowindex="2" role="cell">-0.865</td></tr><tr role="row" style="---0: 1;  --0: -1.0929;  --1: 0.2386; "><th aria-colindex="1" aria-rowindex="3" aria-sort="ascending" role="cell" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">-1.093</td><td aria-colindex="3" aria-rowindex="3" role="cell">0.239</td></tr><tr role="row" style="---0: 2;  --0: 0.0195;  --1: -1.1152; "><th aria-colindex="1" aria-rowindex="4" aria-sort="descending" role="cell" scope="row">2</th><td aria-colindex="2" aria-rowindex="4" role="cell">0.020</td><td aria-colindex="3" aria-rowindex="4" role="cell">-1.115</td></tr><tr role="row" style="---0: 3;  --0: -1.1773;  --1: 0.8309; "><th aria-colindex="1" aria-rowindex="5" aria-sort="ascending" role="cell" scope="row">3</th><td aria-colindex="2" aria-rowindex="5" role="cell">-1.177</td><td aria-colindex="3" aria-rowindex="5" role="cell">0.831</td></tr><tr role="row" style="---0: 4;  --0: 0.1297;  --1: -0.9314; "><th aria-colindex="1" aria-rowindex="6" aria-sort="descending" role="cell" scope="row">4</th><td aria-colindex="2" aria-rowindex="6" role="cell">0.130</td><td aria-colindex="3" aria-rowindex="6" role="cell">-0.931</td></tr><tr role="row" style="---0: 5;  --0: -0.8101;  --1: 0.6705; "><th aria-colindex="1" aria-rowindex="7" aria-sort="ascending" role="cell" scope="row">5</th><td aria-colindex="2" aria-rowindex="7" role="cell">-0.810</td><td aria-colindex="3" aria-rowindex="7" role="cell">0.671</td></tr><tr role="row" style="---0: 6;  --0: 1.8823;  --1: 0.0001; "><th aria-colindex="1" aria-rowindex="8" aria-sort="descending" role="cell" scope="row">6</th><td aria-colindex="2" aria-rowindex="8" role="cell">1.882</td><td aria-colindex="3" aria-rowindex="8" role="cell">0.000</td></tr><tr role="row" style="---0: 7;  --0: 0.6700;  --1: -0.2205; "><th aria-colindex="1" aria-rowindex="9" aria-sort="descending" role="cell" scope="row">7</th><td aria-colindex="2" aria-rowindex="9" role="cell">0.670</td><td aria-colindex="3" aria-rowindex="9" role="cell">-0.220</td></tr><tr role="row" style="---0: 8;  --0: -1.3456;  --1: 0.8641; "><th aria-colindex="1" aria-rowindex="10" aria-sort="ascending" role="cell" scope="row">8</th><td aria-colindex="2" aria-rowindex="10" role="cell">-1.346</td><td aria-colindex="3" aria-rowindex="10" role="cell">0.864</td></tr><tr role="row" style="---0: 9;  --0: -0.7459;  --1: -0.4826; "><th aria-colindex="1" aria-rowindex="11" aria-sort="ascending" role="cell" scope="row">9</th><td aria-colindex="2" aria-rowindex="11" role="cell">-0.746</td><td aria-colindex="3" aria-rowindex="11" role="cell">-0.483</td></tr><tr role="row" style="---0: 10;  --0: -0.7701;  --1: 0.3620; "><th aria-colindex="1" aria-rowindex="12" aria-sort="ascending" role="cell" scope="row">10</th><td aria-colindex="2" aria-rowindex="12" role="cell">-0.770</td><td aria-colindex="3" aria-rowindex="12" role="cell">0.362</td></tr><tr role="row" style="---0: 11;  --0: 0.3465;  --1: 0.2227; ">< ...
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>activate baseline plot styling</label><style id="xy-options-style-0" media="none">#xy {
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     tr {
#         background: unset;
#         transition: 5s all linear;
#         display: flex; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#     }
# }
#
# }</style></li><li><label><input aria-controls="xy-options-style-1" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in x</label><style id="xy-options-style-1" media="none">#xy {
# --X: 1;
#
# }</style></li><li><label><input aria-controls="xy-options-style-2" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in y</label><style id="xy-options-style-2" media="none">#xy {
# --Y: 1;
#
# }</style></li></ul></form><style id="xy-style">#xy tr { --x: var(--0);
# --y: var(--1);
#  }#xy {
# font-size: .5rem;
# tr:hover {
#     font-size: 1.5rem;
# }
#
# }</style><script id="xy-script">function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }document.querySelectorAll("#xy [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script></section>, id='xy')

# %%
# %%
#
# ```css
# [href="#demo"] {
#     background: -moz-element(#xy);
#     background-size: contain;
#     font-size: 10rem;
# }
# ```
# Out:
# '[href="#demo"] {\n    background: -moz-element(#xy);\n    background-size: contain;\n    font-size: 10rem;\n}\n'
