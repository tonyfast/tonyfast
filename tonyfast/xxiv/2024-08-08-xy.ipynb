# %% [markdown]
# # table to xy plot
#
# [demo](#xy)

# %%
# %%
#
#     import nbconvert_a11y.table
#     DataFrame(numpy.random.randn(20, 2), columns=list("xy")).table(id="xy", caption="randomly generated data that transforms into a 2d plot.").style(
# ```css
# tr:hover {
#     font-size: 2rem;
# }
# ```
#     ).checkbox({
#         ("activate baseline plot styling", True):
# ```css
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     border-left: solid blue;
#     border-right: solid blue;
#     border-top: solid red;
#     border-bottom: solid red;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 translateY(.5rem)
#                 ;
#         }
#     }
# }
# ```
#     , ("distribute markers in x", True):
# ```css
# --X: 1;
# ```
#     , ("distribute markers in y", True):
# ```css
# --Y: 1;
# ```
#     }).radiogroup({
#     ("axis to the left", True) :
# ```css
# ```
#
#     , "center data":
# ```css
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
# ```
#     , "axis to the right":
# ```css
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
# ```
#
#     }, name="origins")
# Out:
# Table(object=           x         y
# 0  -1.670613  1.082452
# 1  -0.584562 -0.950022
# 2  -0.624550 -1.050188
# 3  -1.794908  1.401926
# 4   0.244795 -0.967546
# 5   1.052245 -0.165240
# 6  -0.906341  0.321787
# 7   0.567584  1.497545
# 8   0.076428 -1.020055
# 9   0.623779 -0.167465
# 10 -1.081626  1.423269
# 11  0.687462  1.536124
# 12 -0.821323 -1.307235
# 13  0.619830  0.100830
# 14  0.211649  1.414363
# 15  1.153408 -0.036873
# 16 -0.219424  0.582963
# 17  0.883847  0.029839
# 18  0.575753 -1.423535
# 19  1.262348  2.267642, options=None, html=<section aria-labelledby="xy-figcaption"><figure><table aria-colcount="3" aria-rowcount="24" id="xy" role="table" style="---0-min: 0; ---0-max: 19; ---0-diff: 19; ---0-magnitude: 2; --0-min: -1.7949; --0-max: 1.2623; --0-diff: 3.0573; --1-min: -1.4235; --1-max: 2.2676; --1-diff: 3.6912;"><caption id="xy-caption">pandas dataframe with 20 rows, 2 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row"><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="cell" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" role="cell">'x'</th><th aria-colindex="3" aria-rowindex="1" role="cell">'y'</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style="---0: 0;  --0: -1.6706;  --1: 1.0825; "><th aria-colindex="1" aria-rowindex="2" aria-sort="ascending" role="cell" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">-1.671</td><td aria-colindex="3" aria-rowindex="2" role="cell">1.082</td></tr><tr role="row" style="---0: 1;  --0: -0.5846;  --1: -0.9500; "><th aria-colindex="1" aria-rowindex="3" aria-sort="descending" role="cell" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">-0.585</td><td aria-colindex="3" aria-rowindex="3" role="cell">-0.950</td></tr><tr role="row" style="---0: 2;  --0: -0.6245;  --1: -1.0502; "><th aria-colindex="1" aria-rowindex="4" aria-sort="descending" role="cell" scope="row">2</th><td aria-colindex="2" aria-rowindex="4" role="cell">-0.625</td><td aria-colindex="3" aria-rowindex="4" role="cell">-1.050</td></tr><tr role="row" style="---0: 3;  --0: -1.7949;  --1: 1.4019; "><th aria-colindex="1" aria-rowindex="5" aria-sort="ascending" role="cell" scope="row">3</th><td aria-colindex="2" aria-rowindex="5" role="cell">-1.795</td><td aria-colindex="3" aria-rowindex="5" role="cell">1.402</td></tr><tr role="row" style="---0: 4;  --0: 0.2448;  --1: -0.9675; "><th aria-colindex="1" aria-rowindex="6" aria-sort="descending" role="cell" scope="row">4</th><td aria-colindex="2" aria-rowindex="6" role="cell">0.245</td><td aria-colindex="3" aria-rowindex="6" role="cell">-0.968</td></tr><tr role="row" style="---0: 5;  --0: 1.0522;  --1: -0.1652; "><th aria-colindex="1" aria-rowindex="7" aria-sort="descending" role="cell" scope="row">5</th><td aria-colindex="2" aria-rowindex="7" role="cell">1.052</td><td aria-colindex="3" aria-rowindex="7" role="cell">-0.165</td></tr><tr role="row" style="---0: 6;  --0: -0.9063;  --1: 0.3218; "><th aria-colindex="1" aria-rowindex="8" aria-sort="ascending" role="cell" scope="row">6</th><td aria-colindex="2" aria-rowindex="8" role="cell">-0.906</td><td aria-colindex="3" aria-rowindex="8" role="cell">0.322</td></tr><tr role="row" style="---0: 7;  --0: 0.5676;  --1: 1.4975; "><th aria-colindex="1" aria-rowindex="9" aria-sort="ascending" role="cell" scope="row">7</th><td aria-colindex="2" aria-rowindex="9" role="cell">0.568</td><td aria-colindex="3" aria-rowindex="9" role="cell">1.498</td></tr><tr role="row" style="---0: 8;  --0: 0.0764;  --1: -1.0201; "><th aria-colindex="1" aria-rowindex="10" aria-sort="descending" role="cell" scope="row">8</th><td aria-colindex="2" aria-rowindex="10" role="cell">0.076</td><td aria-colindex="3" aria-rowindex="10" role="cell">-1.020</td></tr><tr role="row" style="---0: 9;  --0: 0.6238;  --1: -0.1675; "><th aria-colindex="1" aria-rowindex="11" aria-sort="descending" role="cell" scope="row">9</th><td aria-colindex="2" aria-rowindex="11" role="cell">0.624</td><td aria-colindex="3" aria-rowindex="11" role="cell">-0.167</td></tr><tr role="row" style="---0: 10;  --0: -1.0816;  --1: 1.4233; "><th aria-colindex="1" aria-rowindex="12" aria-sort="ascending" role="cell" scope="row">10</th><td aria-colindex="2" aria-rowindex="12" role="cell">-1.082</td><td aria-colindex="3" aria-rowindex="12" role="cell">1.423</td></tr><tr role="row" style="---0: 11;  --0: 0.6875;  --1: 1.5361;  ...
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>activate baseline plot styling</label><style id="xy-options-style-0" media="all">#xy {
# --h: 300px;
# --w: 800px;
# --X: 0;
# --Y: 0;
# transition: 5s all linear;
# height: var(--h); width: var(--w);
# thead, tfoot, caption{display: none;}
# tbody {
#     transition: 5s all linear;
#     height: var(--h); width: var(--w);
#     display: block; position: relative;
#     --cx: 0px;
#     --cy: 0px;
#     border-left: solid blue;
#     border-right: solid blue;
#     border-top: solid red;
#     border-bottom: solid red;
#     tr {
#         padding: .5em;
#         background: unset;
#         transition: 5s all linear;
#         display: block; position: absolute;
#         transform:
#             translateX(calc(var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)))
#             translateY(calc(var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#             translate(-50%, -50%)
#             ;
#         &::before, &::after {
#             display: table-cell; position: absolute;
#             counter-reset: index var(---0);
#             content: counter(index);
#             width: 100%;
#             text-align: center;
#             transition: 5s all linear;
#             padding: .5em;
#         }
#         &::before {
#             color: blue;
#             transform:
#                 translateX(calc(var(--cx) - var(--X) * (var(--0) - var(--0-min)) / var(--0-diff) * var(--w)));
#
#         }
#         &::after {
#             color: red;
#             transform:
#                 translateY(calc(var(--cy) - var(--Y) * (var(--1) - var(--1-min)) / var(--1-diff) * var(--h)))
#                 translateY(-100%)
#                 translateY(.5rem)
#                 ;
#         }
#     }
# }
#
# }</style></li><li><label><input aria-controls="xy-options-style-1" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in x</label><style id="xy-options-style-1" media="all">#xy {
# --X: 1;
#
# }</style></li><li><label><input aria-controls="xy-options-style-2" checked="" name="options" onchange='document.querySelectorAll(`[name=options][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="checkbox"/>distribute markers in y</label><style id="xy-options-style-2" media="all">#xy {
# --Y: 1;
#
# }</style></li></ul><ul role="none"><li><label><input aria-controls="xy-origins-style-0" checked="" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the left</label><style id="xy-origins-style-0" media="all">#xy {
#
# }</style></li><li><label><input aria-controls="xy-origins-style-1" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>center data</label><style id="xy-origins-style-1" media="none">#xy {
# tbody {
#     --cx: calc(-1 * var(--0-min) / var(--0-diff) * var(--w));
#     --cy: calc(-1 * var(--1-min) / var(--1-diff) * var(--h));
# }
#
# }</style></li><li><label><input aria-controls="xy-origins-style-2" name="origins" onchange='document.querySelectorAll(`[name=origins][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });' type="radio"/>axis to the right</label><style id="xy-origins-style-2" media="none">#xy {
# tbody {
#     --cx: var(--w);
#     --cy: var(--h);
# }
#
# }</style></li></ul></form><style id="xy-style">#xy tr { --x: var(--0);
# --y: var(--1);
#  }#xy {
# tr:hover {
#     font-size: 2rem;
# }
#
# }</style><script id="xy-script">function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }document.querySelectorAll("#xy [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script></section>, id='xy')

# %%
# %%
#
# ```css
# [href="#xy"] {
#     background: -moz-element(#xy);
#     background-size: contain;
#     font-size: 10rem;
# }
# ```
# Out:
# '[href="#xy"] {\n    background: -moz-element(#xy);\n    background-size: contain;\n    font-size: 10rem;\n}\n'
