# %% [markdown]
# # a table of blobs

# %%
import sklearn.datasets, nbconvert_a11y.t
DataFrame(
    *sklearn.datasets.make_blobs([10]*10, 3), list("xyz")
).rename_axis("group").groupby("group").pipe(
    nbconvert_a11y.t.get_table, id="blobs",
    caption="randomly generated blobs from the tinder of a table."
)
# Out:
# <table aria-colcount="4" aria-rowcount="101" id="blobs" role="table" style="--x-min: -9.239634783496705;--y-min: -10.095197095455834;--z-min: -11.214043670680612;--x-max: 9.52861892707587;--y-max: 11.280025897256879;--z-max: 9.743045821329293;"><caption>randomly generated blobs from the tinder of a table.</caption><tbody role="rowgroup" style="--group: 0;"><tr role="row" style="--x: 0.7887838774047462;--y: 3.1002480450320187;--z: -9.11858997171122;"><th aria-colindex="1" aria-rowindex="2" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">0.79</td><td aria-colindex="3" aria-rowindex="2" role="cell">3.10</td><td aria-colindex="4" aria-rowindex="2" role="cell">-9.12</td></tr><tr role="row" style="--x: 0.33157379799675135;--y: 2.556157084119554;--z: -10.63579120392373;"><th aria-colindex="1" aria-rowindex="3" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="3" role="cell">0.33</td><td aria-colindex="3" aria-rowindex="3" role="cell">2.56</td><td aria-colindex="4" aria-rowindex="3" role="cell">-10.64</td></tr><tr role="row" style="--x: 2.4929938724060023;--y: 3.4902033628626596;--z: -9.552646788139624;"><th aria-colindex="1" aria-rowindex="4" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="4" role="cell">2.49</td><td aria-colindex="3" aria-rowindex="4" role="cell">3.49</td><td aria-colindex="4" aria-rowindex="4" role="cell">-9.55</td></tr><tr role="row" style="--x: 1.993273059117611;--y: 1.4388428464583116;--z: -9.114932349788392;"><th aria-colindex="1" aria-rowindex="5" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="5" role="cell">1.99</td><td aria-colindex="3" aria-rowindex="5" role="cell">1.44</td><td aria-colindex="4" aria-rowindex="5" role="cell">-9.11</td></tr><tr role="row" style="--x: 0.07238780006495471;--y: 2.9687224083442842;--z: -11.025210993347683;"><th aria-colindex="1" aria-rowindex="6" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="6" role="cell">0.07</td><td aria-colindex="3" aria-rowindex="6" role="cell">2.97</td><td aria-colindex="4" aria-rowindex="6" role="cell">-11.03</td></tr><tr role="row" style="--x: 0.7564278308176746;--y: 1.944624208916001;--z: -11.214043670680612;"><th aria-colindex="1" aria-rowindex="7" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="7" role="cell">0.76</td><td aria-colindex="3" aria-rowindex="7" role="cell">1.94</td><td aria-colindex="4" aria-rowindex="7" role="cell">-11.21</td></tr><tr role="row" style="--x: 1.663045221159142;--y: 1.8890454047040908;--z: -10.701805927563267;"><th aria-colindex="1" aria-rowindex="8" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="8" role="cell">1.66</td><td aria-colindex="3" aria-rowindex="8" role="cell">1.89</td><td aria-colindex="4" aria-rowindex="8" role="cell">-10.70</td></tr><tr role="row" style="--x: -0.2521462589728374;--y: 2.372934457996491;--z: -9.371624977059618;"><th aria-colindex="1" aria-rowindex="9" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="9" role="cell">-0.25</td><td aria-colindex="3" aria-rowindex="9" role="cell">2.37</td><td aria-colindex="4" aria-rowindex="9" role="cell">-9.37</td></tr><tr role="row" style="--x: 2.1834555772326114;--y: 2.4668818916754667;--z: -9.021267936824213;"><th aria-colindex="1" aria-rowindex="10" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="10" role="cell">2.18</td><td aria-colindex="3" aria-rowindex="10" role="cell">2.47</td><td aria-colindex="4" aria-rowindex="10" role="cell">-9.02</td></tr><tr role="row" style="--x: 2.411716101234225;--y: 2.4882277825975345;--z: -8.712972777150348;"><th aria-colindex="1" aria-rowindex="11" role="colheader" scope="col">0</th><td aria-colindex="2" aria-rowindex="11" role="cell">2.41</td><td aria-colindex="3" aria-rowindex="11" role="cell">2.49</td><td aria-colindex="4" aria-rowindex="11" role="cell">-8.71</td></tr></tbody><thead role="rowgroup ...

# %%
# %%
# ```css
# #blobs {
#     --h: 400px;
#     --w: 600px;
#     --zz: 1000px;
#     transform-style: preserve-3d;
#     display: block;
#     height: var(--h); width: var(--w);
#     position: relative;
#     --dx: calc(var(--x-max) - var(--x-min));
#     --dy: calc(var(--y-max) - var(--y-min));
#     --dz: calc(var(--z-max) - var(--z-min));
#     tbody {
#         height: var(--h); width: var(--w);
#         position: sticky;
#         top: 0;
#         tr {
#             border: 2px solid rgb(calc(255 / var(--group)), 0, 0);
#             --x-frac: calc((var(--x) - var(--x-min)) / var(--dx));
#             --y-frac: calc((var(--y) - var(--y-min)) / var(--dy));
#             --z-frac: calc((var(--z) - var(--z-min)) / var(--dz));
#             position: absolute;
#             transform: translate3d(
#                 calc(var(--x-frac) * var(--w)),
#                 calc(var(--y-frac) * var(--h)),
#                 calc(var(--z-frac) * var(--zz))
#             );
#         }
#     }
# }
# ```
# Out:
# <style>#blobs {
#     --h: 400px;
#     --w: 600px;
#     --zz: 1000px;
#     transform-style: preserve-3d;
#     display: block;
#     height: var(--h); width: var(--w);
#     position: relative;
#     --dx: calc(var(--x-max) - var(--x-min));
#     --dy: calc(var(--y-max) - var(--y-min));
#     --dz: calc(var(--z-max) - var(--z-min));
#     tbody {
#         height: var(--h); width: var(--w);
#         position: sticky;
#         top: 0;
#         tr {
#             border: 2px solid rgb(calc(255 / var(--group)), 0, 0);
#             --x-frac: calc((var(--x) - var(--x-min)) / var(--dx));
#             --y-frac: calc((var(--y) - var(--y-min)) / var(--dy));
#             --z-frac: calc((var(--z) - var(--z-min)) / var(--dz));
#             position: absolute;
#             transform: translate3d(
#                 calc(var(--x-frac) * var(--w)),
#                 calc(var(--y-frac) * var(--h)),
#                 calc(var(--z-frac) * var(--zz))
#             );
#         }
#     }
# }
# </style>
# <pre><code class="css">#blobs {
#     --h: 400px;
#     --w: 600px;
#     --zz: 1000px;
#     transform-style: preserve-3d;
#     display: block;
#     height: var(--h); width: var(--w);
#     position: relative;
#     --dx: calc(var(--x-max) - var(--x-min));
#     --dy: calc(var(--y-max) - var(--y-min));
#     --dz: calc(var(--z-max) - var(--z-min));
#     tbody {
#         height: var(--h); width: var(--w);
#         position: sticky;
#         top: 0;
#         tr {
#             border: 2px solid rgb(calc(255 / var(--group)), 0, 0);
#             --x-frac: calc((var(--x) - var(--x-min)) / var(--dx));
#             --y-frac: calc((var(--y) - var(--y-min)) / var(--dy));
#             --z-frac: calc((var(--z) - var(--z-min)) / var(--dz));
#             position: absolute;
#             transform: translate3d(
#                 calc(var(--x-frac) * var(--w)),
#                 calc(var(--y-frac) * var(--h)),
#                 calc(var(--z-frac) * var(--zz))
#             );
#         }
#     }
# }
# </code></pre>
