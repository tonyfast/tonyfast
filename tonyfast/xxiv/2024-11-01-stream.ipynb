# %% [markdown]
# # november 1, 2024 stream
#
# during the video we talk about [a recent calligraphy piece i did with
# an accompanying literate program](2024-10-31-abcdfuck.ipynb). the goal is start thinking beyond alt text
# toward a real experience of the calligraphy for screen readers.
# we demonstrate the humble beginnings of this concept with a mobile
# screen reader demo.
# we're not there yet, but this is an important step.
#
# the first half uses some previously drawn calligraphy,
# and the second half watches calligraphy being drawn.
# during this portion we talk about the shape of the [literate computing course](https://github.com/Gadfly-ai/literate-computing-1/tree/a627c304ed5c4cefccf989bed7a7b57ab0a49824)
# from the perspective of 7 words.

# %%
# %%html
# <iframe width="857" height="614" src="https://www.youtube.com/embed/cMWruLvrKi0" title="literate programming course and calligraphy" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="857" height="614" src="https://www.youtube.com/embed/cMWruLvrKi0" title="literate programming course and calligraphy" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## imagining the digital accessibility of hand drawn letters
#
# ![image.png](attachment:4cb5e0db-c14d-47ab-ac41-31a21220f26c.png)
#
# we explore a [previous post the combines dataframes and cursive alphabet
# to create a tactile and keyboard experience](2024-10-31-abcdfuck.ipynb).
# we check out the [`jupyter-bbox-widget`](https://github.com/gereleth/jupyter-bbox-widget) for annotating images then perform pandas and css formatted tables
# to acheive our goals.

# %% [markdown]
# ## hand drawn syllabus
#
# ![image.png](attachment:5eaa1025-cfb1-45ec-b1d5-ba26aaa42aa3.png)
#
# the second half of the stream i take some time to write out the weekly
# topics that are covered in the course.
#
# <figure>
# <figcaption>a hand drawn syllabus for the literate computing course followed by an explicit list</figcaption>
#
# <img src=https://raw.githubusercontent.com/Gadfly-ai/literate-computing-1/a627c304ed5c4cefccf989bed7a7b57ab0a49824/docs/media/syllabus_sm.jpg >
#
# <ol aria-label="syllabus">
#     <li>literacy</li>
#     <li>hypermedia</li>
#     <li>collage</li>
#     <li>testing</li>
#     <li>aesthetics</li>
#     <li>demoing</li>
#     <li>publishing</li>
# </ol>
#
# </figure>
