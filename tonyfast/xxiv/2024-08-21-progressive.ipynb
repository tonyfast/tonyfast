# %% [markdown]
# # progressive table enhancement

# %%
# %%
#     df =  DataFrame(numpy.random.randn(10, 4),  columns=list("wxyz"))
# all of our numerical columns are potential fodder for positions the data.
# the `none` options indicates that the table is relatively positioned.
# any other value indices absolute positioning that dimension.
#
#     from nbconvert_a11y.table import new, aria
#     table = df.table()
#     table.html.form.append(fieldset := new("fieldset", new("legend", "plotting")))
#     for axis in "XYZ":
#         fieldset.append(new("label", axis, new("select", *(
#             new("option", column, value=i, name=column) for i, column in enumerate(["none"] + df.columns.tolist(), -1)),
#                             onchange=
# ```javascript
# swapVar(this); swapClass(this);
# ```
#                             , name=axis, **aria(controls=table.id), **{"data-class": "x"})))
#     fieldset.append(new("label", "width", new("input", type="number", value=600)))
#     # fieldset.append(new("label", "units", ))
#     fieldset.append(new("label", "height", new("input", type="number", value=400)))
#     # fieldset.append(new("label", "units", ))
#     fieldset.append(new("label", "depth", new("input", type="number", value=0)))
#     # fieldset.append(new("label", "units", ))
#
#     table.html.append(new("script",
# ```javascript
# function swapVar(element) {
#                               console.log(element);
#     let option = element.selectedOptions[0]
#         target = document.getElementById(element.getAttribute(`aria-controls`));
#     if (option.value < 0 ) {
#
#     } else {
#         target.style.setProperty(`--${element.name}-min`, `var(--${option.value}-min)`);
#         target.style.setProperty(`--${element.name}-max`, `var(--${option.value}-max)`);
#         target.querySelectorAll("tr").forEach(pr
#             (x) => {
#                 x.style.setProperty(`--${element.name}`, `var(--${option.value})`);
#             }
#         );
#     }
# }
# function swapClass(element) {
#     let option = element.selectedOptions[0];
#     target.classList.toggle(element.name, option.value > -1);
# }
# function swapStyle(element) {
#     let target = document.getElementById(element.getAttribute(`aria-controls`));
#     target.setAttribute(`media`, element.checked ?  `none` : `all`);
# }
# ```
#     ))
#
#     table.html.form.append(fieldset := new('fieldset', new("legend", "visibility")))
#     for i, name in enumerate(df.index.names, 1):
#         fieldset.append(
#             new("label", new("input", onchange="swapStyle(this)", type="checkbox", checked="", **aria(controls=F"{table.id}-col--{i}-style")), str(name))
#         )
#         fieldset.append(new("style", """
#             #%s tr th:nth-of-type(%i) {display: none;}
#             """ % (name, i), id =F"{table.id}-col--{i}-style", media="none"))
#     for j, row in enumerate(df.columns.values, 1):
#         fieldset.append(
#             new("label", new("input", onchange="swapStyle(this)", type="checkbox", checked="", **aria(controls=F"{table.id}-col-{j}-style")), str(row))
#         )
#         fieldset.append(new("style", """
#         #%s {
#             tbody tr td:nth-of-type(%i){display: none;}
#             thead tr th:nth-of-type(%i) {display: none;}
#         }
#         """ % (table.id, j, i + j), id =F"{table.id}-col-{j}-style", media="none"))
#     table.html.table.tbody.attrs.update({"class": "grid"})
#     table.html.append(new("style",
# ```css
# @property --width {syntax: "<number>"; inherits: true; initial-value: 600;}
# @property --uX {syntax: "<length>"; inherits: true; initial-value: 1px;}
# @property --X-dir {syntax: "<number>"; inherits: true; initial-value: 1;}
# @property --Y-dir {syntax: "<number>"; inherits: true; initial-value: 1;}
# @property --X-dir {syntax: "<number>"; inherits: true; initial-value: 1;}
# @property --height {syntax: "<number>"; inherits: true; initial-value: 400;}
# @property --uY {syntax: "<length>"; inherits: true; initial-value: 1px;}
# @property --depth {syntax: "<number>"; inherits: true; initial-value: 10;}
# @property --distance {syntax: "<number>"; inherits: true; initial-value: 36;}
# @property --uZ {syntax: "<length>"; inherits: true; initial-value: 1in;}
# @property --time {syntax: "<time>"; inherits: true; initial-value: 2s;}
#
# :root {
#     --WIDTH: calc(var(--width) * var(--uX));
#     --HEIGHT: calc(var(--height) * var(--uY));
#     --DEPTH: calc(var(--depth) * var(--uZ));
#
# }
#
# table:is(.X, .Y, .Z) {
#     width: var(--WIDTH);
#     tbody {
#         &.grid {
#             background:
#                 linear-gradient(0deg, transparent 99%, lightblue 1%),
#                 linear-gradient(90deg, transparent 99%, lightblue 1%)
#                 ;
#             background-size:
#                 100px 100px,
#                 100px 100px
#                 ;
#         }
#         padding: 50px;
#         transform-style: preserve-3d;
#         border: solid 1px;
#         position: relative;
#         width: fit-content;
#         display: flex;
#         flex-direction: column;
#         tr {
#             display: flex;
#             flex-direction: row;
#             width: fit-content;
#             transform-style: preserve-3d;
#             transition: all calc(var(--time) + 1s) linear;
#             border: solid 2px;
#             th, td{
#                 border: solid 3px;
#             }
#         }
#     }
# }
# table.Z tbody {
#     tr {
#         --dZ: calc((var(--Z) - var(--Z-min)) / (var(--Z-max) - var(--Z-min)));
#         display: block;
#         position: relative;
#         transform-origin: 50% 50%;
#         transform:
#             perspective(calc(var(--distance) * var(--uZ)))
#             translateZ(calc(var(--dZ) * var(--DEPTH)))
#             ;
#     }
# }
# table.Y tbody {
#     height: var(--HEIGHT);
#     tr {
#         position: absolute;
#         --dY: calc((var(--Y) - var(--Y-min)) / (var(--Y-max) - var(--Y-min)));
#         transform:
#             translateY(calc(var(--dY) * var(--HEIGHT)))
#             translate(0, -50%)
#             ;
#     }
# }
# table.X tbody {
#     width: var(--WIDTH);
#     tr {
#         --dX: calc((var(--X) - var(--X-min)) / (var(--X-max) - var(--X-min)));
#         transform:
#             translateX(calc(var(--dX) * var(--WIDTH)))
#             ;
#     }
# }
# table.X.Y tbody {
#     tr {
#         transform:
#             translateX(calc(var(--dX) * var(--WIDTH)))
#             translateY(calc(var(--dY) * var(--HEIGHT)))
#             translate(-50%, -50%)
#             ;
#     }
# }
# table.Y.Z tbody {
#     tr {
#         transform-origin: 50% calc(var(--HEIGHT) / 2);
#         transform:
#             perspective(calc(var(--distance) * var(--uZ)))
#             translateZ(calc(var(--dZ) * var(--DEPTH)))
#             translateY(calc(var(--dY) * var(--HEIGHT)))
#             translate(0, -50%)
#             ;
#     }
# }
# table.X.Z tbody {
#     tr {
#         transform-origin: calc(var(--WIDTH) / 2) 50%;
#         transform:
#             perspective(calc(var(--distance) * var(--uZ)))
#             translateZ(calc(var(--dZ) * var(--DEPTH)))
#             translateX(calc(var(--dX) * var(--WIDTH)))
#             ;
#     }
# }
# table.X.Y.Z tbody {
#     tr {
#         transform-origin: calc(var(--WIDTH) / 2) calc(var(--HEIGHT) / 2);
#         transform:
#             perspective(calc(var(--distance) * var(--uZ)))
#             translateZ(calc(var(--dZ) * var(--DEPTH)))
#             translateX(calc(var(--dX) * var(--WIDTH)))
#             translateY(calc(var(--dY) * var(--HEIGHT)))
#             translate(-50%, -50%)
#             ;
#     }
# }
# ```
#     ))
#     HTML(table.html)
# Out:
# '<section aria-labelledby="ae12d48ba-figcaption" id="ae12d48ba-region"><figure><figcaption id="ae12d48ba-figcaption"></figcaption><table aria-colcount="5" aria-labelledby="ae12d48ba-figcaption ae12d48ba-caption" aria-rowcount="14" id="ae12d48ba" role="table" style="---0-min: 0; ---0-max: 9; ---0-diff: 9; --0-min: -1.2072; --0-max: 1.2559; --0-diff: 2.4631; --1-min: -1.6344; --1-max: 1.1087; --1-diff: 2.7432; --2-min: -1.7978; --2-max: 1.8939; --2-diff: 3.6917; --3-min: -1.4249; --3-max: 1.6656; --3-diff: 3.0905;"><caption id="ae12d48ba-caption">pandas dataframe with 10 rows, 4 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row" style=\'---0: &lt;th aria-colindex="1" aria-rowindex="1" aria-sort="ascending" role="colheader" style=""&gt;None&lt;/th&gt;;  ---1: &lt;th aria-colindex="2" aria-rowindex="1" role="colheader" style=""&gt;w&lt;/th&gt;;  ---2: &lt;th aria-colindex="3" aria-rowindex="1" role="colheader" style=""&gt;x&lt;/th&gt;;  ---3: &lt;th aria-colindex="4" aria-rowindex="1" role="colheader" style=""&gt;y&lt;/th&gt;;  ---4: &lt;th aria-colindex="5" aria-rowindex="1" role="colheader" style=""&gt;z&lt;/th&gt;; \'><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="colheader" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" role="colheader">w</th><th aria-colindex="3" aria-rowindex="1" role="colheader">x</th><th aria-colindex="4" aria-rowindex="1" role="colheader">y</th><th aria-colindex="5" aria-rowindex="1" role="colheader">z</th></tr></thead><tbody class="grid" role="rowgroup" style="--g: 0; "><tr role="row" style=\'---0: 0; ---1: &lt;th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="rowheader" scope="row" style="---0: 0; "&gt;0&lt;/th&gt;;  --0: 1.2559;  --1: 0.1916;  --2: 0.1091;  --3: -0.0531; \'><th aria-colindex="1" aria-rowindex="2" aria-sort="descending" role="rowheader" scope="row">0</th><td aria-colindex="2" aria-rowindex="2" role="cell">1.256</td><td aria-colindex="3" aria-rowindex="2" role="cell">0.192</td><td aria-colindex="4" aria-rowindex="2" role="cell">0.109</td><td aria-colindex="5" aria-rowindex="2" role="cell">-0.053</td></tr><tr role="row" style=\'---0: 1; ---1: &lt;th aria-colindex="1" aria-rowindex="3" role="rowheader" scope="row" style="---0: 1; "&gt;1&lt;/th&gt;;  --0: -0.2198;  --1: 0.0174;  --2: -0.2363;  --3: 0.5838; \'><th aria-colindex="1" aria-rowindex="3" role="rowheader" scope="row">1</th><td aria-colindex="2" aria-rowindex="3" role="cell">-0.220</td><td aria-colindex="3" aria-rowindex="3" role="cell">0.017</td><td aria-colindex="4" aria-rowindex="3" role="cell">-0.236</td><td aria-colindex="5" aria-rowindex="3" role="cell">0.584</td></tr><tr role="row" style=\'---0: 2; ---1: &lt;th aria-colindex="1" aria-rowindex="4" role="rowheader" scope="row" style="---0: 2; "&gt;2&lt;/th&gt;;  --0: -1.2072;  --1: -1.5596;  --2: 0.6044;  --3: -0.9143; \'><th aria-colindex="1" aria-rowindex="4" role="rowheader" scope="row">2</th><td aria-colindex="2" aria-rowindex="4" role="cell">-1.207</td><td aria-colindex="3" aria-rowindex="4" role="cell">-1.560</td><td aria-colindex="4" aria-rowindex="4" role="cell">0.604</td><td aria-colindex="5" aria-rowindex="4" role="cell">-0.914</td></tr><tr role="row" style=\'---0: 3; ---1: &lt;th aria-colindex="1" aria-rowindex="5" role="rowheader" scope="row" style="---0: 3; "&gt;3&lt;/th&gt;;  --0: 0.0744;  --1: -0.2741;  --2: -0.0182;  --3: 1.6656; \'><th aria-colindex="1" aria-rowindex="5" role="rowheader" scope="row">3</th><td aria-colindex="2" aria-rowindex="5" role="cell">0.074</td><td aria-colindex="3" aria-rowindex="5" role="cell">-0.274</td><td aria-colindex="4" aria-rowindex="5" role="cell">-0.018</td><td aria-colindex="5" aria-rowindex="5" role="cell">1.666</td></tr><tr role="row" style=\'---0: 4; ---1: &lt;th aria-colindex="1" aria-rowindex="6" role="rowheader" scope="row" style="---0: 4; "&gt;4&lt;/th&gt;;  --0: 0.6374;  --1: 1.10 ...
# <pre><code>df =  DataFrame(numpy.random.randn(10, 4),  columns=list(&quot;wxyz&quot;))
# </code></pre>
# <p>all of our numerical columns are potential fodder for positions the data.
# the <code>none</code> options indicates that the table is relatively positioned.
# any other value indices absolute positioning that dimension.</p>
# <pre><code>from nbconvert_a11y.table import new, aria
# table = df.table()
# table.html.form.append(fieldset := new(&quot;fieldset&quot;, new(&quot;legend&quot;, &quot;plotting&quot;)))
# for axis in &quot;XYZ&quot;:
#     fieldset.append(new(&quot;label&quot;, axis, new(&quot;select&quot;, *(
#         new(&quot;option&quot;, column, value=i, name=column) for i, column in enumerate([&quot;none&quot;] + df.columns.tolist(), -1)),
#                         onchange=
# </code></pre>
# <pre><code class="javascript"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span>swapVar(<span style="color: #008000; font-weight: bold">this</span>);<span style="color: #bbbbbb"> </span>swapClass(<span style="color: #008000; font-weight: bold">this</span>);
# </pre></div>
# </code></pre>
# <pre><code>                        , name=axis, **aria(controls=table.id), **{&quot;data-class&quot;: &quot;x&quot;})))
# fieldset.append(new(&quot;label&quot;, &quot;width&quot;, new(&quot;input&quot;, type=&quot;number&quot;, value=600)))
# # fieldset.append(new(&quot;label&quot;, &quot;units&quot;, ))
# fieldset.append(new(&quot;label&quot;, &quot;height&quot;, new(&quot;input&quot;, type=&quot;number&quot;, value=400)))
# # fieldset.append(new(&quot;label&quot;, &quot;units&quot;, ))
# fieldset.append(new(&quot;label&quot;, &quot;depth&quot;, new(&quot;input&quot;, type=&quot;number&quot;, value=0)))
# # fieldset.append(new(&quot;label&quot;, &quot;units&quot;, ))
#
# table.html.append(new(&quot;script&quot;,
# </code></pre>
# <pre><code class="javascript"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span><span style="color: #008000; font-weight: bold">function</span><span style="color: #bbbbbb"> </span>swapVar(element)<span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">                              </span>console.log(element);
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">let</span><span style="color: #bbbbbb"> </span>option<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span>element.selectedOptions[<span style="color: #666666">0</span>]
# <span style="color: #bbbbbb">        </span>target<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span><span style="color: #008000">document</span>.getElementById(element.getAttribute(<span style="color: #BA2121">`aria-controls`</span>));
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">if</span><span style="color: #bbbbbb"> </span>(option.value<span style="color: #bbbbbb"> </span><span style="color: #666666">&lt;</span><span style="color: #bbbbbb"> </span><span style="color: #666666">0</span><span style="color: #bbbbbb"> </span>)<span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">        </span>
# <span style="color: #bbbbbb">    </span>}<span style="color: #bbbbbb"> </span><span style="color: #008000; font-weight: bold">else</span><span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">        </span>target.style.setProperty(<span style="color: #BA2121">`--</span><span style="color: #A45A77; font-weight: bold">${</span>element.name<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">-min`</span>,<span style="color: #bbbbbb"> </span><span style="color: #BA2121">`var(--</span><span style="color: #A45A77; font-weight: bold">${</span>option.value<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">-min)`</span>);
# <span style="color: #bbbbbb">        </span>target.style.setProperty(<span style="color: #BA2121">`--</span><span style="color: #A45A77; font-weight: bold">${</span>element.name<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">-max`</span>,<span style="color: #bbbbbb"> </span><span style="color: #BA2121">`var(--</span><span style="color: #A45A77; font-weight: bold">${</span>option.value<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">-max)`</span>);
# <span style="color: #bbbbbb">        </span>target.querySelectorAll(<span style="color: #BA2121">&quot;tr&quot;</span>).forEach(pr
# <span style="color: #bbbbbb">            </span>(x)<span style="color: #bbbbbb"> </span>=&gt;<span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">                </span>x.style.setProperty(<span style="color: #BA2121">`--</span><span style="color: #A45A77; font-weight: bold">${</span>element.name<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">`</span>,<span style="color: #bbbbbb"> </span><span style="color: #BA2121">`var(--</span><span style="color: #A45A77; font-weight: bold">${</span>option.value<span style="color: #A45A77; font-weight: bold">}</span><span style="color: #BA2121">)`</span>);
# <span style="color: #bbbbbb">            </span>}
# <span style="color: #bbbbbb">        </span>);
# <span style="color: #bbbbbb">    </span>}
# }
# <span style="color: #008000; font-weight: bold">function</span><span style="color: #bbbbbb"> </span>swapClass(element)<span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">let</span><span style="color: #bbbbbb"> </span>option<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span>element.selectedOptions[<span style="color: #666666">0</span>];
# <span style="color: #bbbbbb">    </span>target.classList.toggle(element.name,<span style="color: #bbbbbb"> </span>option.value<span style="color: #bbbbbb"> </span><span style="color: #666666">&gt;</span><span style="color: #bbbbbb"> </span><span style="color: #666666">-1</span>);
# }
# <span style="color: #008000; font-weight: bold">function</span><span style="color: #bbbbbb"> </span>swapStyle(element)<span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">    </span><span style="color: #008000; font-weight: bold">let</span><span style="color: #bbbbbb"> </span>target<span style="color: #bbbbbb"> </span><span style="color: #666666">=</span><span style="color: #bbbbbb"> </span><span style="color: #008000">document</span>.getElementById(element.getAttribute(<span style="color: #BA2121">`aria-controls`</span>));
# <span style="color: #bbbbbb">    </span>target.setAttribute(<span style="color: #BA2121">`media`</span>,<span style="color: #bbbbbb"> </span>element.checked<span style="color: #bbbbbb"> </span><span style="color: #666666">?</span><span style="color: #bbbbbb">  </span><span style="color: #BA2121">`none`</span><span style="color: #bbbbbb"> </span><span style="color: #666666">:</span><span style="color: #bbbbbb"> </span><span style="color: #BA2121">`all`</span>);
# }
# </pre></div>
# </code></pre>
# <pre><code>))
#
# table.html.form.append(fieldset := new('fieldset', new(&quot;legend&quot;, &quot;visibility&quot;)))
# for i, name in enumerate(df.index.names, 1):
#     fieldset.append(
#         new(&quot;label&quot;, new(&quot;input&quot;, onchange=&quot;swapStyle(this)&quot;, type=&quot;checkbox&quot;, checked=&quot;&quot;, **aria(controls=F&quot;{table.id}-col--{i}-style&quot;)), str(name))
#     )
#     fieldset.append(new(&quot;style&quot;, &quot;&quot;&quot;
#         #%s tr th:nth-of-type(%i) {display: none;}
#         &quot;&quot;&quot; % (name, i), id =F&quot;{table.id}-col--{i}-style&quot;, media=&quot;none&quot;))
# for j, row in enumerate(df.columns.values, 1):
#     fieldset.append(
#         new(&quot;label&quot;, new(&quot;input&quot;, onchange=&quot;swapStyle(this)&quot;, type=&quot;checkbox&quot

# %% [markdown]
# some notes on the design:
# * every numerical column offers a feature space for formal representation
# * plotting may switch between scatter, bar, line
# * columns are features that with views that can be toggled from visual, none, nonvisual, css
# * visualization transforms tables from relative positioning to absolute positioning.
# * need to be able to visually swat the axes

# %% [markdown]
# visualization is generally not to be tactile, and if it is the controls are defined in feature spaces.
# they are offered as something to behold, the author displays their power in controlling information 💪
# what if we designed or representations for others to explore. what if we transition from fine art to folk art, from MOMA to meow wolf.
# there is a terrible void i feel observing calder sculptures from a distance.
# when you see pictures of him, he is joyfully inside his sculptures, we observe the sculpture from a passive viewpoint while inside is active.
# the goal of assistive visualization to facilitate the data experience as formal representations.
# the control space changes when working with tables.
# > Tables are not pictures of data: they are catalogues of data to be perused, parsed, referenced and interrogated.
# > A well-designed table will enable the information to be read and understood, and will reveal the patterns and correlations inherent in the data.
# >> https://alistapart.com/article/web-typography-tables/

# %% [markdown]
# a visualization is an artifact
# a table is an archive

# %% [markdown]
# add toggle for the visibility of the features.s
