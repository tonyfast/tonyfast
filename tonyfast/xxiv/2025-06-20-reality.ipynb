# %% [markdown]
# # annotating calligraphy - reality bytes

# %%
import bs4, jupyter_bbox_widget

# %%
if "bboxes" not in locals():
    bboxes = jupyter_bbox_widget.BBoxWidget(bboxes=json.loads(Path("reality_bboxes.jpeg.json").read_text()))
(bboxes := jupyter_bbox_widget.BBoxWidget(image="Downloads/reality copy 2.jpeg", classes="""
reality defined by what it ain't
it is what it is?
reality doesn't impress me
it is what it ain't
tangle weave
notebook
rug
""".strip().splitlines(), bboxes=bboxes.bboxes))
# Out:
# BBoxWidget(bboxes=[{'x': 285, 'y': 638, 'width': 74, 'height': 59, 'label': 'tangle weave'}, {'x': 259, 'y': 4…

# %%
# %%
#     thing = partial(partial, operator.setitem, locals())
# <sup><abbr title="tangle&weave">TW</abbr></sup> certified
#
#     thing("tangle weave")\
# a tangle&weave monogram jawn
#
#     thing("notebook")\
# a soft moleskine notebook single ruled showing the right side of the page with the left folded back
#
#     thing("rug")\
# the work rests on shag rug i've had forever with the remains art projects past stuck in the weave
#
#     thing("reality doesn't impress me")\
# a quote from  🇫🇷 author [anaïs nin](https://en.wikipedia.org/wiki/Ana%C3%AFs_Nin)
#
#     thing("it is what it ain't")\
# ain't
#
#     thing("it is what it is?")\
# is
#
#     thing("reality defined by what it ain't")\
# reality
#
#     (df := DataFrame(bboxes.bboxes))
#     df = df.assign(description=df.label.apply(locals().get))
#     Path("reality_bboxes.jpeg.json").write_text(json.dumps(bboxes.bboxes))
#     df
# Out:
#      x    y  width  height                             label  \
# 0  285  638     74      59                      tangle weave
# 1  259  451     97      96               it is what it ain't
# 2  106  234    197     205        reality doesn't impress me
# 3  434  116    105     106                 it is what it is?
# 4  126  138    395     460  reality defined by what it ain't
# 5   29   79    531     638                          notebook
# 6    1    4    595     792                               rug
#
#                                          description
# 0                       a tangle&weave monogram jawn
# 1                                              ain't
# 2  a quote from  🇫🇷 author [anaïs nin](https://en...
# 3                                                 is
# 4                                            reality
# 5  a soft moleskine notebook single ruled showing...
# 6  the work rests on shag rug i've had forever wi...
# ...

# %% [markdown]
# ## marginalia
#
# * no semantics the area approach
# * i can get the same effect with other semantics, but still leave the option for richer sematnics
# * richer semantics give layer audio in aira label and description
#
# * the proximity of words is important
