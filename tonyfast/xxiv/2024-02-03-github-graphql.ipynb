# %% [markdown]
# # gathering metadata on assistive technology
#
# using github graphql api to gather metadata about
# projects tagged with assistive technology.

# %% [markdown]
# this exploration looks specifically at assistive technology tags.
# this might be a good _training_ set for a more open general search
# that tries to differentiate between assistive tech presenting and the real deal.

# %%
    __import__("dotenv").load_dotenv()
    client = __import__("python_graphql_client").GraphqlClient(
        "https://api.github.com/graphql", dict(Authorization=F"token {os.environ['GITHUB_TOKEN']}")
    )

# %%
# %%
#     async def search_one(query, after=None):
# <details><summary>the graphql query</summary>
#
# with REST, you get what you get. with grapql, you get what you ask for.
#
#         return await client.execute_async(
# ```graphql
# {
#       search(query: "%s", type: REPOSITORY, first: 50, after: %s) {
#         repositoryCount
#     wikiCount
#     pageInfo {
#       hasNextPage
#       endCursor
#     }
#     edges {
#       node {
#         ... on Repository {
#           url
#           id
#           stargazerCount
#           forkCount
#           description
#           issues {
#             totalCount
#           }
#             languages(first: 20) {
#             nodes {
#               name
#             }
#             }
#           fundingLinks {
#             platform
#             url
#           }
#           pullRequests {
#             totalCount
#           }
#           updatedAt
#           object(expression: "HEAD:README.md") {
#             ... on Blob {
#               text
#             }
#           }
#           repositoryTopics(first: 20) {
#             edges {
#               node {
#                 topic {
#                   name
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#       }
#     }
# ```
#         % (query, str(after and F'"{after}"' or "null")))
# Out:
# <pre><code>async def search_one(query, after=None):
# </code></pre>
# <details><summary>the graphql query</summary>
# <p>with REST, you get what you get. with grapql, you get what you ask for.</p>
# <pre><code>    return await client.execute_async(
# </code></pre>
# <pre><code class="graphql"><div class="highlight"><pre><span></span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">      </span><span class="n" title="Name">search</span><span class="p" title="Punctuation">(</span><span class="n" title="Name">query</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="s" title="Literal.String">&quot;%s&quot;</span><span class="p" title="Punctuation">,</span><span class="w" title="Text.Whitespace"> </span><span class="n" title="Name">type</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="no" title="Name.Constant">REPOSITORY</span><span class="p" title="Punctuation">,</span><span class="w" title="Text.Whitespace"> </span><span class="n" title="Name">first</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="mi" title="Literal.Number.Integer">50</span><span class="p" title="Punctuation">,</span><span class="w" title="Text.Whitespace"> </span><span class="n" title="Name">after</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="err" title="Error">%</span><span class="no" title="Name.Constant">s</span><span class="p" title="Punctuation">)</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">        </span><span class="n" title="Name">repositoryCount</span>
# <span class="w" title="Text.Whitespace">    </span><span class="n" title="Name">wikiCount</span>
# <span class="w" title="Text.Whitespace">    </span><span class="n" title="Name">pageInfo</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">      </span><span class="n" title="Name">hasNextPage</span>
# <span class="w" title="Text.Whitespace">      </span><span class="n" title="Name">endCursor</span>
# <span class="w" title="Text.Whitespace">    </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">    </span><span class="n" title="Name">edges</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">      </span><span class="n" title="Name">node</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">        </span><span class="p" title="Punctuation">...</span><span class="w" title="Text.Whitespace"> </span><span class="k" title="Keyword">on</span><span class="w" title="Text.Whitespace"> </span><span class="nc" title="Name.Class">Repository</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">url</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">id</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">stargazerCount</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">forkCount</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">description</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">issues</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">totalCount</span>
# <span class="w" title="Text.Whitespace">          </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">languages</span><span class="p" title="Punctuation">(</span><span class="n" title="Name">first</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="mi" title="Literal.Number.Integer">20</span><span class="p" title="Punctuation">)</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">nodes</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">              </span><span class="n" title="Name">name</span>
# <span class="w" title="Text.Whitespace">            </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">            </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">fundingLinks</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">platform</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">url</span>
# <span class="w" title="Text.Whitespace">          </span><span class="p" title="Punctuation">}</span><span class="w" title="Text.Whitespace">      </span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">pullRequests</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">totalCount</span>
# <span class="w" title="Text.Whitespace">          </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">updatedAt</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">object</span><span class="p" title="Punctuation">(</span><span class="n" title="Name">expression</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="s" title="Literal.String">&quot;HEAD:README.md&quot;</span><span class="p" title="Punctuation">)</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="p" title="Punctuation">...</span><span class="w" title="Text.Whitespace"> </span><span class="k" title="Keyword">on</span><span class="w" title="Text.Whitespace"> </span><span class="nc" title="Name.Class">Blob</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">              </span><span class="n" title="Name">text</span>
# <span class="w" title="Text.Whitespace">            </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">          </span><span class="p" title="Punctuation">}</span>
# <span class="w" title="Text.Whitespace">          </span><span class="n" title="Name">repositoryTopics</span><span class="p" title="Punctuation">(</span><span class="n" title="Name">first</span><span class="p" title="Punctuation">:</span><span class="w" title="Text.Whitespace"> </span><span class="mi" title="Literal.Number.Integer">20</span><span class="p" title="Punctuation">)</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">            </span><span class="n" title="Name">edges</span><span class="w" title="Text.Whitespace"> </span><span class="p" title="Punctuation">{</span>
# <span class="w" title="Text.Whitespace">

# %%
# %%
#     async def search(query, stop=20):
# [paginate through a search results](https://til.simonwillison.net/github/graphql-pagination-python) and collect the results.
#
#         queries = [await search_one(query)]
#         ct = 1
#         while queries[-1]["data"]["search"]:
#             if info := queries[-1]["data"]["search"].get("pageInfo"):
#                 if info["hasNextPage"]:
#                     print(queries[-1]["data"]["search"]["pageInfo"]["endCursor"])
#                     queries.append(await search_one(query, queries[-1]["data"]["search"]["pageInfo"]["endCursor"]))
#                     print(F"done {ct}")
#                     ct += 1
#                     if ct == stop: break
#                     continue
#             break
#         return queries
# Out:
# <pre><code>async def search(query, stop=20):
# </code></pre>
# <p><a href="https://til.simonwillison.net/github/graphql-pagination-python">paginate through a search results</a> and collect the results.</p>
# <pre><code>    queries = [await search_one(query)]
#     ct = 1
#     while queries[-1][&quot;data&quot;][&quot;search&quot;]:
#         if info := queries[-1][&quot;data&quot;][&quot;search&quot;].get(&quot;pageInfo&quot;):
#             if info[&quot;hasNextPage&quot;]:
#                 print(queries[-1][&quot;data&quot;][&quot;search&quot;][&quot;pageInfo&quot;][&quot;endCursor&quot;])
#                 queries.append(await search_one(query, queries[-1][&quot;data&quot;][&quot;search&quot;][&quot;pageInfo&quot;][&quot;endCursor&quot;]))
#                 print(F&quot;done {ct}&quot;)
#                 ct += 1
#                 if ct == stop: break
#                 continue
#         break
#     return queries</code></pre>

# %%
df = DataFrame(results := await search("topic:assistive-technology", 1))
# Out:
# Y3Vyc29yOjUw
# done 1
# Y3Vyc29yOjEwMA==
# done 2
# Y3Vyc29yOjE1MA==
# done 3
# Y3Vyc29yOjIwMA==
# done 4
# Y3Vyc29yOjI1MA==
# done 5
# Y3Vyc29yOjMwMA==
# done 6

# %% [markdown]
# https://github.com/a11yhood/research/blob/main/2025-01-14-graphql.ipynb

# %%
data = df["data"].series(
)["search"].series(
)["edges"].explode(
).series()["node"].series().set_index("id")
data.pullRequests = data.pullRequests.itemgetter("totalCount")
data.issues = data.issues.itemgetter("totalCount")
data["README"] = data.pop("object").itemgetter("text")

data = data.join(
    data.pop("repositoryTopics").series()["edges"]
    .explode().itemgetter("node").itemgetter("topic").itemgetter("name")
    .groupby(level=0).agg(list).rename("topics")
)

# %%
data
# Out:
#                                                                                 url  \
# id
# R_kgDOItjjpA                         https://github.com/ai-collection/ai-collection
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==                 https://github.com/OptiKey/OptiKey
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==         https://github.com/brunopulis/awesome-a11y
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=            https://github.com/Stypox/dicio-android
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==               https://github.com/cboard-org/cboard
# ...                                                                             ...
# R_kgDOKqLtnQ                      https://github.com/makersmakingchange/Single-M...
# R_kgDOImJzBg                             https://github.com/obstino-org/facecontrol
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==                   https://github.com/scify/Memor-i
# R_kgDONVmIKQ                      https://github.com/raketyonex/Geniee-Teacher-A...
# R_kgDONsTpRQ                      https://github.com/anisarisdamayanti/Walking-S...
#
#                                   stargazerCount  forkCount  \
# id
# R_kgDOItjjpA                                7833        778
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==            4310        506
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==            1838        145
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=             862         78
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==             667        176
# ...                                          ...        ...
# R_kgDOKqLtnQ                                   0          0
# R_kgDOImJzBg                                   0          0
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==               0          3
# R_kgDONVmIKQ                                   0          0
# R_kgDONsTpRQ                                   0          0
#
#                                                                         description  \
# id
# R_kgDOItjjpA                      The Generative AI Landscape - A Collection of ...
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==  OptiKey - Full computer control and speech wit...
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==                           A curate list about A11Y
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=                    Dicio assistant app for Android
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==  Augmentative and Alternative Communication (AA...
# ...                                                                             ...
# R_kgDOKqLtnQ                      Guide for modifying commercial message playbac...
# R_kgDOImJzBg                                               Face Control Android app
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==                                               None
# R_kgDONVmIKQ                      Assistant for teachers to generate quiz questi...
# R_kgDONsTpRQ                      Smart walking stick for visually impaired indi...
#
#                                   issues  \
# id
# R_kgDOItjjpA                          59
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==     503
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==      20
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=     183
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==     596
# ...                                  ...
# R_kgDOKqLtnQ                           0
# R_kgDOImJzBg                           0
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==       0
# R_kgDONVmIKQ                           0
# R_kgDONsTpRQ                           0
#
#                                                                        fundingLinks  \
# id
# R_kgDOItjjpA                      [{'platform': 'LIBERAPAY', 'url': 'https://lib...
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==  [{'platform': 'GITHUB', 'url': 'https://github...
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==  [{'platform': 'GITHUB', 'url': 'https://github...
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=  [{'platform': 'LIBERAPAY', 'url': 'https://lib...
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==  [{'platform': 'OPEN_COLLECTIVE', 'url': 'https...
# ...                                                                             ...
# R_kgDOKqLtnQ                                                                     []
# R_kgDOImJzBg                                                                     []
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==                                                 []
# R_kgDONVmIKQ                                                                     []
# R_kgDONsTpRQ                                                                     []
#
#                                   pullRequests             updatedAt  \
# id
# R_kgDOItjjpA                               639  2025-02-04T14:22:26Z
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==           413  2025-02-04T00:19:56Z
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==           160  2025-02-01T08:06:28Z
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=            86  2025-02-01T18:56:22Z
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==          1200  2025-01-25T01:42:45Z
# ...                                        ...                   ...
# R_kgDOKqLtnQ                                 0  2024-03-27T19:04:23Z
# R_kgDOImJzBg                                 0  2024-11-05T12:31:52Z
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==             8  2024-12-12T22:47:00Z
# R_kgDONVmIKQ                                 0  2024-12-31T16:51:23Z
# R_kgDONsTpRQ                                 0  2025-02-04T17:54:19Z
#
#                                                                              README  \
# id
# R_kgDOItjjpA                      # <img width="20" style="margin-right:6px;" al...
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==  # OptiKey\n\nOptiKey is an on-screen keyboard ...
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==  # Awesome Accessibility\n\n[![Awesome](https:/...
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=  # Dicio assistant\n\nDicio is a *free and open...
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==  [![Digital public good](https://github.com/cbo...
# ...                                                                             ...
# R_kgDOKqLtnQ                      # Single Message Playback Switch\nThe Single M...
# R_kgDOImJzBg                      ## **Face Control Android app**\n### Face Cont...
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==  \n# Memor-i | Memory Game for the visually imp...
# R_kgDONVmIKQ                                                                   None
# R_kgDONsTpRQ                      # 🚀 Walking-Stick: Smart Walking Stick for Vis...
#
#                                                                              topics
# id
# R_kgDOItjjpA                      [artificial-intelligence, collections, ai, ass...
# MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==  [eye-tracking, eyetracking, eye-tracker, eyes,...
# MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==  [accessibility, wai-aria, wcag, a11y, awesome-...
# MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=  [assistant, assistive-technology, personal-ass...
# MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==  [aac, autism, cerebral-palsy, progressive-web-...
# ...                                                                             ...
# R_kgDOKqLtnQ                      [accessibility, assistive-technology, disabili...
# R_kgDOImJzBg                      [accessibility, assistive-switch, assistive-te...
# MDEwOlJlcG9zaXRvcnk2ODAxNDA5MA==  [assistive-technology, java, javafx, javafx-ap...
# R_kgDONVmIKQ                      [assistive-technology, generative-ai, llm, pyt...
# R_kgDONsTpRQ                      [arduino, assistive-technology, audio-out, emb...
#
# [306 rows x 10 columns]

# %%
data.topics.explode().value_counts().to_frame("count").T.style.set_caption(
    "the column titles are the tags of the returned search results and their counts are in the cells below"
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af93e">
#   <caption>the column titles are the tags of the returned search results and their counts are in the cells below</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >topics</th>
#       <th id="T_af93e_level0_col0" class="col_heading level0 col0" >assistive-technology</th>
#       <th id="T_af93e_level0_col1" class="col_heading level0 col1" >accessibility</th>
#       <th id="T_af93e_level0_col2" class="col_heading level0 col2" >openat</th>
#       <th id="T_af93e_level0_col3" class="col_heading level0 col3" >python</th>
#       <th id="T_af93e_level0_col4" class="col_heading level0 col4" >disability</th>
#       <th id="T_af93e_level0_col5" class="col_heading level0 col5" >artificial-intelligence</th>
#       <th id="T_af93e_level0_col6" class="col_heading level0 col6" >arduino</th>
#       <th id="T_af93e_level0_col7" class="col_heading level0 col7" >aac</th>
#       <th id="T_af93e_level0_col8" class="col_heading level0 col8" >machine-learning</th>
#       <th id="T_af93e_level0_col9" class="col_heading level0 col9" >wcag</th>
#       <th id="T_af93e_level0_col10" class="col_heading level0 col10" >ai</th>
#       <th id="T_af93e_level0_col11" class="col_heading level0 col11" >open-source</th>
#       <th id="T_af93e_level0_col12" class="col_heading level0 col12" >assistant</th>
#       <th id="T_af93e_level0_col13" class="col_heading level0 col13" >eye-tracking</th>
#       <th id="T_af93e_level0_col14" class="col_heading level0 col14" >wai-aria</th>
#       <th id="T_af93e_level0_col15" class="col_heading level0 col15" >screen-reader</th>
#       <th id="T_af93e_level0_col16" class="col_heading level0 col16" >3d-printing</th>
#       <th id="T_af93e_level0_col17" class="col_heading level0 col17" >mouse-emulation</th>
#       <th id="T_af93e_level0_col18" class="col_heading level0 col18" >joystick</th>
#       <th id="T_af93e_level0_col19" class="col_heading level0 col19" >computer-vision</th>
#       <th id="T_af93e_level0_col20" class="col_heading level0 col20" >voice-assistant</th>
#       <th id="T_af93e_level0_col21" class="col_heading level0 col21" >a11y</th>
#       <th id="T_af93e_level0_col22" class="col_heading level0 col22" >python3</th>
#       <th id="T_af93e_level0_col23" class="col_heading level0 col23" >deep-learning</th>
#       <th id="T_af93e_level0_col24" class="col_heading level0 col24" >disabilities</th>
#       <th id="T_af93e_level0_col25" class="col_heading level0 col25" >speech-recognition</th>
#       <th id="T_af93e_level0_col26" class="col_heading level0 col26" >android</th>
#       <th id="T_af93e_level0_col27" class="col_heading level0 col27" >communication</th>
#       <th id="T_af93e_level0_col28" class="col_heading level0 col28" >open-hardware</th>
#       <th id="T_af93e_level0_col29" class="col_heading level0 col29" >text-to-speech</th>
#       <th id="T_af93e_level0_col30" class="col_heading level0 col30" >asterics-main</th>
#       <th id="T_af93e_level0_col31" class="col_heading level0 col31" >switch-control</th>
#       <th id="T_af93e_level0_col32" class="col_heading level0 col32" >human-computer-interaction</th>
#       <th id="T_af93e_level0_col33" class="col_heading level0 col33" >hardware</th>
#       <th id="T_af93e_level0_col34" class="col_heading level0 col34" >voice-recognition</th>
#       <th id="T_af93e_level0_col35" class="col_heading level0 col35" >assistive</th>
#       <th id="T_af93e_level0_col36" class="col_heading level0 col36" >raspberry-pi</th>
#       <th id="T_af93e_level0_col37" class="col_heading level0 col37" >ios</th>
#       <th id="T_af93e_level0_col38" class="col_heading level0 col38" >mouse</th>
#       <th id="T_af93e_level0_col39" class="col_heading level0 col39" >hacktoberfest</th>
#       <th id="T_af93e_level0_col40" class="col_heading level0 col40" >xbox-controller</th>
#       <th id="T_af93e_level0_col41" class="col_heading level0 col41" >voice-control</th>
#       <th id="T_af93e_level0_col42" class="col_heading level0 col42" >virtual-keyboard</th>
#       <th id="T_af93e_level0_col43" class="col_heading level0 col43" >lipsync</th>
#       <th id="T_af93e_level0_col44" class="col_heading level0 col44" >lip-mouse</th>
#       <th id="T_af93e_level0_col45" class="col_heading level0 col45" >voice-commands</th>
#       <th id="T_af93e_level0_col46" class="col_heading level0 col46" >mouth-mouse</th>
#       <th id="T_af93e_level0_col47" class="col_heading level0 col47" >switch</th>
#       <th id="T_af93e_level0_col48" class="col_heading level0 col48" >awesome</th>
#       <th id="T_af93e_level0_col49" class="col_heading level0 col49" >circuitpython</th>
#       <th id="T_af93e_level0_col50" class="col_heading level0 col50" >assistive-robotics</th>
#       <th id="T_af93e_level0_col51" class="col_heading level0 col51" >keyboard-emulation</th>
#       <th id="T_af93e_level0_col52" class="col_heading level0 col52" >robotics</th>
#       <th id="T_af93e_level0_col53" class="col_heading level0 col53" >opencv</th>
#       <th id="T_af93e_level0_col54" class="col_heading level0 col54" >special-needs</th>
#       <th id="T_af93e_level0_col55" class="col_heading level0 col55" >keyboard</th>
#       <th id="T_af93e_level0_col56" class="col_heading level0 col56" >blindness</th>
#       <th id="T_af93e_level0_col57" class="col_heading level0 col57" >android-application</th>
#       <th id="T_af93e_level0_col58" class="col_heading level0 col58" >signal-processing</th>
#       <th id="T_af93e_level0_col59" class="col_heading level0 col59" >face-tracking</th>
#       <th id="T_af93e_level0_col60" class="col_heading level0 col60" >ocr-recognition</th>
#       <th id="T_af93e_level0_col61" class="col_heading level0 col61" >environmental-control</th>
#       <th id="T_af93e_level0_col62" class="col_heading level0 col62" >xbox</th>
#       <th id="T_af93e_level0_col63" class="col_heading level0 col63" >embedded-systems</th>
#       <th id="T_af93e_level0_col64" class="col_heading level0 col64" >pcb</th>
#       <th id="T_af93e_level0_col65" class="col_heading level0 col65" >open-source-hardware</th>
#       <th id="T_af93e_level0_col66" class="col_heading level0 col66" >awesome-list</th>
#       <th id="T_af93e_level0_col67" class="col_heading level0 col67" >education</th>
#       <th id="T_af93e_level0_col68" class="col_heading level0 col68" >dicio-assistant</th>
#       <th id="T_af93e_level0_col69" class="col_heading level0 col69" >personal-assistant-framework</th>
#       <th id="T_af93e_level0_col70" class="col_heading level0 col70" >speech-to-text</th>
#       <th id="T_af93e_level0_col71" class="col_heading level0 col71" >personal-assistant</th>
#       <th id="T_af93e_level0_col72" class="col_heading level0 col72" >api</th>
#       <th id="T_af93e_level0_col73" class="col_heading level0 col73" >cli</th>
#       <th id="T_af93e_level0_col74" class="col_heading level0 col74" >go-baby-go</th>
#       <th id="T_af93e_level0_col75" class="col_heading level0 col75" >dicio</th>
#       <th id="T_af93e_level0_col76" class="col_heading level0 col76" >vuejs</th>
#       <th id="T_af93e_level0_col77" class="col_heading level0 col77" >eye-tracker</th>
#       <th id="T_af93e_level0_col78" class="col_heading level0 col78" >speech-to-code</th>
#       <th id="T_af93e_level0_col79" class="col_heading level0 col79" >gaming</th>
#       <th id="T_af93e_level0_col80" class="col_heading level0 col80" >example</th>
#       <th id="T_af93e_level0_col81" class="col_heading level0 col81" >neural-network</th>
#       <th id="T_af93e_level0_col82" class="col_heading level0 col82" >demo</th>
#       <th id="T_af93e_level0_col83" class="col_heading level0 col83" >voice-programming</th>
#       <th id="T_af93e_level0_col84" class="col_heading level0 col84" >xbox-adaptive-controller</th>
#       <th id="T_af93e_level0_col85" class="col_heading level0 col85" >ape</th>
#       <th id="T_af93e_level0_col86" class="col_heading level0 col86" >switch-access</th>
#       <th id="T_af93e_level0_col87" class="col_heading level0 col87" >firmware</th>
#       <th id="T_af93e_level0_col88" class="col_heading level0 col88" >visuall
