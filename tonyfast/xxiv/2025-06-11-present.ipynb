# %% [markdown]
# # the notebook as a stage
#
# the notebook is a shapeshifter.
# it can present as art, science, and literature.
# this talk explores the relationship of physical and digital notebooks relative to video.
#
# ![image.png](attachment:d091796c-d98d-4059-a650-e97ee92197ec.png)

# %%
# %%
# ## hypertext, hypermedia, and hyperfilm
#
# i've always considered computational notebooks to be hypermedia collages.
# a data visualization is an experience across different media formats: text, visual, audio, haptics.
# from this position, ted nelson is a prophet
#
# [Ted Nelson Coins the Terms Hypertext, Hypermedia, and Hyperlink](https://www.historyofinformation.com/detail.php?id=830)
#
# > Films, sound recordings, and video recordings are also linear strings, bas-
# ically for mechanical reasons. But theses, too, can now be arranged as non-linear
# systems-- for instance, lattices-- for editing purposes, or for display with dif-
# ferent emphasis. (This would naturally require computer control, using the ELF or
# a related system, and various cartridge or re-recording devices.) __The hyperfilm--
# a browsable or vari-sequenced movie-- is only one of the p~ssible hypermedia that
# require our attention__.
#
# > * [Complex information processing: a file structure for the complex, the changing and the indeterminate](https://monoskop.org/File:Nelson_Ted_1965_A_File_Structure_for_the_Complex_the_Changing_and_the_Indeterminate.pdf)
#
# <iframe width="800" height="600" src="https://www.youtube.com/embed/Bqx6li5dbEY" title="Ted Nelson in Herzog&#39;s &quot;Lo and Behold&quot;" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <h2>hypertext, hypermedia, and hyperfilm</h2>
# <p>i've always considered computational notebooks to be hypermedia collages.
# a data visualization is an experience across different media formats: text, visual, audio, haptics.
# from this position, ted nelson is a prophet</p>
# <p><a href="https://www.historyofinformation.com/detail.php?id=830">Ted Nelson Coins the Terms Hypertext, Hypermedia, and Hyperlink</a></p>
# <blockquote>
# <p>Films, sound recordings, and video recordings are also linear strings, bas-
# ically for mechanical reasons. But theses, too, can now be arranged as non-linear
# systems-- for instance, lattices-- for editing purposes, or for display with dif-
# ferent emphasis. (This would naturally require computer control, using the ELF or
# a related system, and various cartridge or re-recording devices.) <strong>The hyperfilm--
# a browsable or vari-sequenced movie-- is only one of the p~ssible hypermedia that
# require our attention</strong>.</p>
# </blockquote>
# ...

# %%
# %%
# ## oriole a learning medium based on jupyter
#
# <details>
#     <summary>Oriole: a new learning medium based on Jupyter + Docker JupyterDay Atlanta, 2016-08-13</summary>
#     <iframe width="100%" height=600 src="https://nbviewer.org/github/jupyterday-atlanta-2016/oriole_jupyterday_atl/blob/d2ce13f243d0c27f3f9c0aa6c6ffed150c0b01cd/oriole_talk.ipynb"></iframe>
# </details>
#
# > in oriole, we get the complete integration of video synchronized with the flow of the text, as well as the ability to execute the code: this is probably as close as we get to learning side-by-side with Peter himself
#
# ### suggestions from oriole and orielly about video content in notebooks
#
# * focus on a concise "unit of thought"
# * invest the time and editorial effort to create a good introduction
# * keep your narrative simple and reasonably linear
# * "chunk" both the text and the code into understandable parts
# * alternate between text, code, output, further links, etc.
# * leverage markdown by providing interesting links for background, deep-dive, etc.
# * code cells should not be long, < 10 lines
# * code cells must show that they've run, producing at least some output
# * load data from the container, not the network
# * clear all output then "Run All" -- or it didn't happen
# * video narratives: there's text, and there's subtext...
# * pause after each "beat" -- smile, breathe, allow people to follow you
# Out:
# <h2>oriole a learning medium based on jupyter</h2>
# <details>
#     <summary>Oriole: a new learning medium based on Jupyter + Docker JupyterDay Atlanta, 2016-08-13</summary>
#     <iframe width="100%" height=600 src="https://nbviewer.org/github/jupyterday-atlanta-2016/oriole_jupyterday_atl/blob/d2ce13f243d0c27f3f9c0aa6c6ffed150c0b01cd/oriole_talk.ipynb"></iframe>
# </details>
# <blockquote>
# <p>in oriole, we get the complete integration of video synchronized with the flow of the text, as well as the ability to execute the code: this is probably as close as we get to learning side-by-side with Peter himself</p>
# </blockquote>
# <h3>suggestions from oriole and orielly about video content in notebooks</h3>
# <ul>
# <li>focus on a concise &quot;unit of thought&quot;</li>
# <li>invest the time and editorial effort to create a good introduction</li>
# <li>keep your narrative simple and reasonably linear</li>
# ...

# %% [markdown]
# ## the economics of presentations are inequitable

# %% [markdown]
# the economics of labor and being visible are forked!
# travel is not safe, not accessible, and bears uncertain risk all while time and spoons are precious.
# notebooks, art, and humor have a way to communicate that presentations eschew. further, there is less space for new work.
#
# streaming and presenting can be a more familiar place to liberate ideas and yourself.
# digital, physical, and lab notebooks are toys for the playful.
# we'll understand the power of notebooks if we can stretch our imagination of them.

# %% [markdown]
# > The poor image is a rag or a rip; an AVI or a
# JPEG, a lumpen proletarian in the class society
# of appearances, ranked and valued according to
# its resolution. __The poor image has been
# uploaded, downloaded, shared, reformatted, and
# reedited. It transforms quality into accessibility,
# exhibition value into cult value, films into clips,
# contemplation into distraction.__ The image is
# liberated from the vaults of cinemas and
# archives and thrust into digital uncertainty, at
# the expense of its own substance. The poor
# image tends towards abstraction: it is a visual
# idea in its very becoming.
#
# > [in defense of the poor image](http://worker01.e-flux.com/pdf/article_94.pdf)
#
# a great notebook, one that is accessible and reproducible, will be mangled in this media mill.
# all the readers, authors, and folks will interact with digital works without any history.
# they'll forget the author and the provenance in efforts to be liberated.

# %%
# %%
# <iframe width="800" height="600" src="https://www.youtube.com/embed/qi3Zgx0Jh9k" title="Marcel Duchamp&#39;s &quot;Anémic cinéma&quot; (1926) | MoMA FILM VAULT SUMMER CAMP" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="800" height="600" src="https://www.youtube.com/embed/qi3Zgx0Jh9k" title="Marcel Duchamp&#39;s &quot;Anémic cinéma&quot; (1926) | MoMA FILM VAULT SUMMER CAMP" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## what does video add?
#
# digital video makes it possible to capture the process. its propelled modern digital cultures like skateboarding, bmx, vogue, roller blading/skating, and calligraphy.
# the work around the work - the parergon - has made these cultures accessible.
#
#
# ```mermaid
# graph LR
#     notebook ---> video
#     video ---> notebook
# ```
#
# we need text for accessibility perspective. `video` and `audio` elements are the only multimodal elements. they can include [`track`](https://developer.mozilla.org/en-US/docs/Web/HTML/Element/track) containing on 4 kinds of tracks: subtitles, captions, chapters, and metadata.

# %%
# %%
# ## video to notebook
#
# the most challenging situation for creating notebook video begins with the silence of a blank notebook.
# in this context, the artist uses improvisational techniques to created a bounded a work in 1 to 1:30 hours.
#
# * scope is most challenging boundary to set
# * prepare you physical space before starting. create an optimal starting point.
# * encourages talking through process as it is captured
# * feelings are expected during the process
#
# ### a live stream creating an accessible heatmap
#
# a live stream creating an accessible visualization for screen reader user using jupyter notebooks.
#
# <iframe width="800" height="600" src="https://www.youtube.com/embed/uF9VpP-mrSE" title="live programming nonvisual data science and heatmaps" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
#
# ### calligraphic programming practices
#
# <iframe width="800" height="600" src="https://www.youtube.com/embed/1yMSyusdjMU" title="live digital calligraphy using code as a pen to visualize words" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <h2>video to notebook</h2>
# <p>the most challenging situation for creating notebook video begins with the silence of a blank notebook.
# in this context, the artist uses improvisational techniques to created a bounded a work in 1 to 1:30 hours.</p>
# <ul>
# <li>scope is most challenging boundary to set</li>
# <li>prepare you physical space before starting. create an optimal starting point.</li>
# <li>encourages talking through process as it is captured</li>
# <li>feelings are expected during the process</li>
# </ul>
# <h3>a live stream creating an accessible heatmap</h3>
# <p>a live stream creating an accessible visualization for screen reader user using jupyter notebooks.</p>
# ...

# %%
# %%
# ## notebook to video
#
# <q>a notebook in the hand is worth two in the bush</q>.
# when we experience a notebook as video it tends to create another
# notebook capturing the viewing expierence.
#
# ### multiplying notebooks
#
# in this case, one notebook becomes two and one video becomes two.
#
# this video creates the final edits on a notebook given as a presentation on accessibility voiced by a screen reader
# for a local meetup.
#
# <iframe width="800" height="600" src="https://www.youtube.com/embed/ewJKZKTW-Ag" title="accessibility talk critique and notebooking" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
# <details>
#     <summary>final video version of the notebook</summary>
#     <iframe width="800" height="600" src="https://www.youtube.com/embed/E62ouB7O5SY" title="practice-abillity" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# </details>
# Out:
# <h2>notebook to video</h2>
# <p><q>a notebook in the hand is worth two in the bush</q>.
# when we experience a notebook as video it tends to create another
# notebook capturing the viewing expierence.</p>
# <h3>multiplying notebooks</h3>
# <p>in this case, one notebook becomes two and one video becomes two.</p>
# <p>this video creates the final edits on a notebook given as a presentation on accessibility voiced by a screen reader
# for a local meetup.</p>
# <iframe width="800" height="600" src="https://www.youtube.com/embed/ewJKZKTW-Ag" title="accessibility talk critique and notebooking" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# <details>
#     <summary>final video version of the notebook</summary>
# ...

# %%
# %%
# ## video of video in the notebook
#
#
# [an extended study of some early modern art](https://nbviewer.org/github/tonyfast/tonyfast/blob/042a0aa50b96b193855e84fc174491003af4b9d4/tonyfast/xxiv/2025-06-10-illusion.ipynb)
#
#
# <iframe width="800" height="600" src="https://www.youtube.com/embed/Gq8-56NAFn0" title="plotting palmer penguins plus pushing praxis presenting points" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <h2>video of video in the notebook</h2>
# <p><a href="https://nbviewer.org/github/tonyfast/tonyfast/blob/042a0aa50b96b193855e84fc174491003af4b9d4/tonyfast/xxiv/2025-06-10-illusion.ipynb">an extended study of some early modern art</a></p>
# <iframe width="800" height="600" src="https://www.youtube.com/embed/Gq8-56NAFn0" title="plotting palmer penguins plus pushing praxis presenting points" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# %%
# ## notebooks as a stream
#
# sometimes a stream might might combine a lot of ideas.
# this is when the notebook shines.
#
# <details>
#     <summary>2024/11/01 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2024-11-01-stream.ipynb?flush_cache=true" height=600 width="100%"></iframe>
# </details>
#
# <details>
#     <summary>2025/04/24 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2025-04-24-stream.ipynb?flush_cache=true" height=600 width="100%"></iframe>
# </details>
#
# <details>
#     <summary>2025/05/03 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2025-05-03-stream.ipynb" height=600 width="100%"></iframe>
# </details>
# Out:
# <h2>notebooks as a stream</h2>
# <p>sometimes a stream might might combine a lot of ideas.
# this is when the notebook shines.</p>
# <details>
#     <summary>2024/11/01 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2024-11-01-stream.ipynb?flush_cache=true" height=600 width="100%"></iframe>
# </details>
# <details>
#     <summary>2025/04/24 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2025-04-24-stream.ipynb?flush_cache=true" height=600 width="100%"></iframe>
# </details>
# <details>
#     <summary>2025/05/03 stream </summary>
#     <iframe src="https://nbviewer.org/github/tonyfast/tonyfast/blob/main/tonyfast/xxiv/2025-05-03-stream.ipynb" height=600 width="100%"></iframe>
# </details>

# %% [markdown]
# ## conclusions
#
# * video is a good mirror for me. pictures, specifically high resolution ones, of myself upset me. i don't have a static perception of my self.
# * video is the most perceivable media type
# * table is the most operable lattice
# * streaming/filming creates organic content. 1 minute of video per hour stream for 3 hours. b-roll matters to folx
# * build a backlog, not viewers. the act/work is the most important

# %% [markdown]
# ## suggestions
#
# download obs and start getting setup.
# it is a process.

# %% [markdown]
# https://www.historyofinformation.com/detail.php?id=830
