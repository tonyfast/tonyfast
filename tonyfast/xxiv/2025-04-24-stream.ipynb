# %% [markdown]
# # ~~dataink~~
#
#
# ~~dataink~~ is live recording exploring accessibility and visualization throught the lens of music theory, semiotics, and critical theories.
# we spend time thinking and drawing critically about 2 essays:
#
# 1. [minimalism and the absurdity of the data-to-ink-ratio](https://www.frank.computer/blog/2025/04/data-to-ink.html) by [frank elavsky](https://www.frank.computer)
# 2. [the silence of the frames](https://www.mtosmt.org/issues/mto.96.2.1/mto.96.2.1.littlefield.html) by richard littlefield
#
# during these ruminations we discuss the work of margaret lieteritz, john cage, jaques derrida, and edward cone.

# %% [markdown]
# ![image.png](attachment:f2f55107-ae25-4ae5-bdbf-60f7259187e4.png)

# %%
# %%html
# ## stream
#
# i enjoyed this most at 1.5x
#
# <iframe width="1431" height="805" src="https://www.youtube.com/embed/0CwXJJb-VFQ" title="silence........... derrida, data, and (data)frames" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# ## stream
#
# i enjoyed this most at 1.5x
#
# <iframe width="1431" height="805" src="https://www.youtube.com/embed/0CwXJJb-VFQ" title="silence........... derrida, data, and (data)frames" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## margaret lieteritz
#
# [![](https://i0.wp.com/ftn-blog.com/wp-content/uploads/2020/09/leiteritz-info.jpg?resize=1106%2C1536)](https://ftn-blog.com/2021/01/14/margaret-leiteritz-1907-1976/)
#
# [![](https://wellness-magazin.at/wp-content/uploads/2019/03/Bildschirmfoto-2019-03-05-um-16.32.25.png)](https://wellness-magazin.at/people/baushaus-die-weibliche-seite/)
#
# margaret is an early bauhaus student with a niche interest in artistic representations of technical figures,
# unfortunately, [many of these pieces were lost to conflict](https://bauhauskooperation.com/wissen/das-bauhaus/koepfe/biografien/biografie-detail/person-Leiteritz-Margaret-725).

# %% [markdown]
# ## screen reader stream mediation
#
# this is the first stream im really happy about the application of the screen reader.
# this technique made it feel like there was another participant in the stream.
# i fumbled around a lot, but the screen reader takes practice.
# the first stream my voice hurt afterwards so i couldn't do it for a few days;
# the screen reader as a voice surrogate for presentation is strong.
# it worked well with having some key configurations mapped to my stream deck so i could use my
# left hand - while drawing with my right - to control the screen reader.
# its really too awkward to control a screen reader with the keyboard AND stream.
# it is a really UX win when we can use our non dominant hand effectively.

# %% [markdown]
# on a personal note, i really didn't hate rewatching this stream to time stamp it. fuck yea therapy!
