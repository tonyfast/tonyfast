# %% [markdown]
# # options for plotting
#
# the default table representation should have an accompanying form to it. in this notebook, we design a common pattern
# form changes views of stylized tables. radio groups and checkbox groups are useful for these styling choicess.

# %%
from nbconvert_a11y.repr import get_table, new
from nbconvert_a11y.table import aria

df = DataFrame(numpy.random.randn(30, 3), None, list("xyz"))
df.iloc[0] *= 0 
df.iloc[-1] = df.iloc[:-1].mean()
section = df.T.pipe(get_table, id="xyz")
section.table.attrs.update(**{"class": "xyz"})
# Out:
# /home/tbone/mambaforge/envs/p311/lib/python3.11/site-packages/pandas/core/algorithms.py:1743: RuntimeWarning: divide by zero encountered in log10
#   return lib.map_infer(values, mapper, convert=convert)

# %%
# %%
#
#     options = {
#         "color everything red":
# ```css
# #xyz {
#     color: red;
# }
# ```
#         .data, "big text":
# ```css
# #xyz{
#     font-size: 300%;
# }
# ```
#
#     .data}

# %%
# %%
#
#     update_view =\
# ```text/javascript
# document.querySelectorAll(`[name=%s][aria-controls]`).forEach((object)=>{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) && target.setAttribute("media", object.checked ? "all" : "none");
# });
# ```

# %%
def choices(options, name, id=None, kind="radio", default=0):
    id = "xyz"
    ul = new("ul")
    for i, (label, css) in enumerate(options.items()):
        id = F"{id}-{name}-style"
        ul.append(new("li", new("label", new("input", type=kind, name=name, onchange=update_view%name, **aria(controls=id)), label), new("style", css, id=id, media="none")))
    return ul

# %%
section.form.append(choices(options, "views"))
section.form.append(choices(options, "checks", kind="checkbox"))
section
# Out:
# <section aria-labelledby="xyz-figcaption"><figure><figcaption id="xyz-figcaption"></figcaption><table aria-colcount="31" aria-rowcount="7" class="xyz" id="xyz" role="table" style="--0-min: 0.0000; --0-max: 0.0000; --0-diff: 0.0000; --1-min: -1.9385; --1-max: -0.1583; --1-diff: 1.7802; --2-min: -2.2581; --2-max: 1.2979; --2-diff: 3.5560; --3-min: -0.0066; --3-max: 1.9074; --3-diff: 1.9140; --4-min: -1.5504; --4-max: 0.4159; --4-diff: 1.9663; --5-min: -0.2617; --5-max: 0.1666; --5-diff: 0.4284; --6-min: -0.2149; --6-max: 1.7277; --6-diff: 1.9425; --7-min: -3.7407; --7-max: -0.0695; --7-diff: 3.6712; --8-min: -0.9036; --8-max: 0.9299; --8-diff: 1.8335; --9-min: -0.9167; --9-max: 0.0724; --9-diff: 0.9891; --20-min: -0.8720; --20-max: 0.5515; --20-diff: 1.4235; --21-min: -1.4702; --21-max: -0.5445; --21-diff: 0.9257; --22-min: 0.1371; --22-max: 1.2042; --22-diff: 1.0671; --23-min: -1.2918; --23-max: 0.5562; --23-diff: 1.8480; --24-min: -0.5514; --24-max: 1.3841; --24-diff: 1.9355; --25-min: -2.1576; --25-max: 0.3927; --25-diff: 2.5503; --26-min: -2.2826; --26-max: 0.7219; --26-diff: 3.0045; --27-min: -0.7158; --27-max: -0.3206; --27-diff: 0.3952; --28-min: -1.2958; --28-max: 1.4617; --28-diff: 2.7574; --29-min: -0.1430; --29-max: -0.0783; --29-diff: 0.0646;"><caption id="xyz-caption">pandas dataframe with 3 rows, 30 columns with 1 index levels and 1 columns levels.</caption><thead role="rowgroup"><tr aria-selected="true" role="row"><th aria-colindex="1" aria-current="true" aria-rowindex="1" aria-sort="ascending" role="cell" tabindex="1">None</th><th aria-colindex="2" aria-rowindex="1" aria-sort="descending" role="cell">0</th><th aria-colindex="3" aria-rowindex="1" role="cell">1</th><th aria-colindex="4" aria-rowindex="1" role="cell">2</th><th aria-colindex="5" aria-rowindex="1" aria-sort="descending" role="cell">3</th><th aria-colindex="6" aria-rowindex="1" role="cell">4</th><th aria-colindex="7" aria-rowindex="1" aria-sort="ascending" role="cell">5</th><th aria-colindex="8" aria-rowindex="1" aria-sort="ascending" role="cell">6</th><th aria-colindex="9" aria-rowindex="1" role="cell">7</th><th aria-colindex="10" aria-rowindex="1" role="cell">8</th><th aria-colindex="11" aria-rowindex="1" role="cell">9</th><th aria-colindex="12" aria-rowindex="1" colspan="10" role="cell" rowspan="1"></th><th aria-colindex="22" aria-rowindex="1" role="cell">20</th><th aria-colindex="23" aria-rowindex="1" role="cell">21</th><th aria-colindex="24" aria-rowindex="1" aria-sort="descending" role="cell">22</th><th aria-colindex="25" aria-rowindex="1" aria-sort="ascending" role="cell">23</th><th aria-colindex="26" aria-rowindex="1" aria-sort="ascending" role="cell">24</th><th aria-colindex="27" aria-rowindex="1" aria-sort="descending" role="cell">25</th><th aria-colindex="28" aria-rowindex="1" role="cell">26</th><th aria-colindex="29" aria-rowindex="1" aria-sort="descending" role="cell">27</th><th aria-colindex="30" aria-rowindex="1" aria-sort="ascending" role="cell">28</th><th aria-colindex="31" aria-rowindex="1" role="cell">29</th></tr></thead><tbody role="rowgroup" style="--g: 0; "><tr role="row" style="---0: x;  --0: 0.0000;  --1: -0.7582;  --2: -2.2581;  --3: 1.9074;  --4: -0.4981;  --5: -0.2617;  --6: -0.2149;  --7: -1.6675;  --8: 0.3290;  --9: 0.0724;  --20: -0.8720;  --21: -0.5445;  --22: 1.2042;  --23: -1.2918;  --24: -0.5514;  --25: 0.3927;  --26: -0.6290;  --27: -0.3206;  --28: -1.2958;  --29: -0.1430; "><th aria-colindex="1" aria-rowindex="2" role="cell" scope="row">'x'</th><td aria-colindex="2" aria-rowindex="2" role="cell">0.000</td><td aria-colindex="3" aria-rowindex="2" role="cell">-0.758</td><td aria-colindex="4" aria-rowindex="2" role="cell">-2.258</td><td aria-colindex="5" aria-rowindex="2" role="cell">1.907</td><td aria-colindex="6" aria-rowindex="2" role="cell">-0.498</td><td aria-colindex="7" aria-rowindex="2" role="cell">-0.262</td><td aria-colindex="8" aria-rowindex="2" role="cell">-0.215</td><td aria-colindex="9" aria-rowindex="2" ro ...
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });
# ' type="radio"/>color everything red</label><style id="xyz-views-style" media="none"><style>#xyz {
#     color: red;
# }
# </style></style></li><li><label><input aria-controls="xyz-views-style-views-style" name="views" onchange='document.querySelectorAll(`[name=views][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });
# ' type="radio"/>big text</label><style id="xyz-views-style-views-style" media="none"><style>#xyz{
#     font-size: 300%;
# }
# </style></style></li></ul><ul><li><label><input aria-controls="xyz-checks-style" name="checks" onchange='document.querySelectorAll(`[name=checks][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });
# ' type="checkbox"/>color everything red</label><style id="xyz-checks-style" media="none"><style>#xyz {
#     color: red;
# }
# </style></style></li><li><label><input aria-controls="xyz-checks-style-checks-style" name="checks" onchange='document.querySelectorAll(`[name=checks][aria-controls]`).forEach((object)=&gt;{
#     var target = document.getElementById(object.getAttribute(`aria-controls`));
#     (target.tagName == `STYLE`) &amp;&amp; target.setAttribute("media", object.checked ? "all" : "none");
# });
# ' type="checkbox"/>big text</label><style id="xyz-checks-style-checks-style" media="none"><style>#xyz{
#     font-size: 300%;
# }
# </style></style></li></ul></form><style id="xyz-style"><style>#xyz tr {  }</style></style><script id="xyz-script">function setScroll(table) {
#     console.log(table);
#     let y = (table.scrollTop) / (table.scrollHeight - table.clientHeight);
#     let x = (table.scrollLeft) / (table.scrollWidth - table.clientWidth);
#     table.style.setProperty("--scroll-y", y);
#     table.style.setProperty("--scroll-x", x);
#     table.dataset.scrollY = y;
#     table.dataset.scrollX = x;
# }document.querySelectorAll("#xyz [data-scroll]").forEach(
#     (element) => {
#         element.onscroll = (element) => {setScroll(element.target)};
#     }
# )</script></section>
