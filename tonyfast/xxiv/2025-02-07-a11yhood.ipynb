# %% [markdown]
# ## aligning `github` and `ravelry`; no `thingiverse` 😤
#
# where is a11yhood as of <time>2/7/2025</time>?
#
# 1. there is an `a11yhood` python command line application for the three scrapers written.
# 2. we can align `github` and `ravelry`, not `thingiverse` because i need to add more api calls
#    to get the right metadata.
# 3. we save scrape and ingest the data using `pandas` then save that data at parquet.
# 4. the search loads the parquet files using `polars` cause we wanna go fast.
#
# plan for the demo
#
# 1. demonstrate aligned search at the command line and in a widget
# 2. walk through [the `a11yhood` github repository](https://github.com/a11yhood/a11yhood)

# %%
# !python -m a11yhood search "eye"
# Out:
# | url                                                         | description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# ...

# %%
    import a11yhood.search
    a11yhood.search.widget()
# Out:
# interactive(children=(Text(value='hat', description='text'), Output()), _dom_classes=('widget-interact',))
# <function a11yhood.search.widget.<locals>.app(text: str = 'hat')>
