# %% [markdown]
# # analyzing `pyproject.toml` configurations of popular projects

# %% [markdown]
# `get_pyproject_config_data` loads a dataframe created in a [previous post].
# it contains the results of a <var>graphql</var> query to posted to the github api
# that returnsthe pyproject files for some of the most popular python projects on github.
#
# [previous post]: 2022-12-09-pyproject-analysis.ipynb

# %%
    # %pip install importnb pandas jinja2 __09_pyproject_analysis
    def get_pyproject_config_data() -> "pandas.DataFrame":
        with importnb.Notebook(): from __09_pyproject_analysis import tidy_configs, tidy_responses, gather, pyproject_query 
        return tidy_configs(df := tidy_responses(responses := gather(pyproject_query, max=15)))

# %% [markdown]
# the shape of our dataframe - `df` from `get_pyproject_config_data` - is:
#
# * on the rows: one project per row
# * on the columns: the keys found in the projects `pyproject.toml`

# %%
    import importnb, pandas
    display((df := get_pyproject_config_data()).head(3))
    F"there are {len(df)} `pyproject.toml` files in the dataset."
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tool  \
# url
# https://github.com/open-telemetry/opentelemetry-python  {'black': {'line-length': 79, 'exclude': '(
#   /(  # generated files
#     .tox|
#     venv|
#     .*/build/lib/.*|
#     exporter/opentelemetry-exporter-jaeger-proto-grpc/src/opentelemetry/exporter/jaeger/proto/grpc/gen|
#     exporter/opentelemetry-exporter-jaeger-thrift/src/opentelemetry/exporter/jaeger/thrift/gen|
#     exporter/opentelemetry-exporter-zipkin-proto-http/src/opentelemetry/exporter/zipkin/proto/http/v2/gen|
#     opentelemetry-proto/src/opentelemetry/proto/.*/.*|
#     scripts
#   )/
# )
# '}, 'pytest': {'ini_options': {'addopts': '-rs -v', 'log_cli': True, 'log_cli_level': 'warning'}}}
# https://github.com/freemocap/freemocap                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'taskipy': {'tasks': {'setup': 'pre-commit install', 'test': 'python -m unittest src/tests/**/test_*', 'installer': './bin/installer.sh', 'format': 'black src/'}}}
# https://github.com/3b1b/manim                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
#
#                                                                                  build-system  \
# url
# https://github.com/open-telemetry/opentelemetry-python                                    NaN
# https://github.com/freemocap/freemocap                                                    NaN
# https://github.com/3b1b/manim                           {'requires': ['setuptools', 'wheel']}
#
#                                                        project mypy flake8
# url
# https://github.com/open-telemetry/opentelemetry-python     NaN  NaN    NaN
# https://github.com/freemocap/freemocap                     NaN  NaN    NaN
# https://github.com/3b1b/manim                              NaN  NaN    NaN
# 'there are 234 `pyproject.toml` files in the dataset.'

# %% [markdown]
# ### what tools are used most?
#
# PEPXXX defines the `tool` key as a place that third party applications can store configuration information.

# %% [markdown]
# when we explode the `df.tool` in `tools` we find a frame with all the third party tools named.

# %%
    (tools := df.tool.dropna().apply(pandas.Series)).head(3).fillna("")
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      black  \
# url
# https://github.com/open-telemetry/opentelemetry-python  {'line-length': 79, 'exclude': '(
#   /(  # generated files
#     .tox|
#     venv|
#     .*/build/lib/.*|
#     exporter/opentelemetry-exporter-jaeger-proto-grpc/src/opentelemetry/exporter/jaeger/proto/grpc/gen|
#     exporter/opentelemetry-exporter-jaeger-thrift/src/opentelemetry/exporter/jaeger/thrift/gen|
#     exporter/opentelemetry-exporter-zipkin-proto-http/src/opentelemetry/exporter/zipkin/proto/http/v2/gen|
#     opentelemetry-proto/src/opentelemetry/proto/.*/.*|
#     scripts
#   )/
# )
# '}
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                                                                                                      pytest  \
# url
# https://github.com/open-telemetry/opentelemetry-python  {'ini_options': {'addopts': '-rs -v', 'log_cli': True, 'log_cli_level': 'warning'}}
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym                               {'ini_options': {'filterwarnings': ['ignore:.*step API.*:DeprecationWarning']}}
#
#                                                                                                                                                                                                         taskipy  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap                  {'tasks': {'setup': 'pre-commit install', 'test': 'python -m unittest src/tests/**/test_*', 'installer': './bin/installer.sh', 'format': 'black src/'}}
# https://github.com/openai/gym
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       pyright  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym                           {'include': ['gym/**', 'tests/**'], 'exclude': ['**/node_modules', '**/__pycache__'], 'strict': [], 'typeCheckingMode': 'basic', 'pythonVersion': '3.6', 'pythonPlatform': 'All', 'typeshedPath': 'typeshed', 'enableTypeIgnoreComments': True, 'reportMissingImports': 'none', 'reportMissingTypeStubs': False, 'reportInvalidTypeVarUse': 'none', 'reportGeneralTypeIssues': 'none', 'reportUntypedFunctionDecorator': 'none', 'reportPrivateUsage': 'warning', 'reportUnboundVariable': 'warning'}
#
#                                                        hatch isort mutmut  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        check-wheel-contents  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        flit coverage  ...  \
# url                                                                   ...
# https://github.com/open-telemetry/opentelemetry-python                ...
# https://github.com/freemocap/freemocap                                ...
# https://github.com/openai/gym                                         ...
#
#                                                        jupyter-releaser  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        check-manifest  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        vendoring commitizen  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        scriv autoflake tbump  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        autopub  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        poetry-version-plugin  \
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
#                                                        typeshed
# url
# https://github.com/open-telemetry/opentelemetry-python
# https://github.com/freemocap/freemocap
# https://github.com/openai/gym
#
# [3 rows x 54 columns]

# %%
    F"there are {len(tools.columns)} tools used in the {len(df)} pyproject.toml files."
# Out:
# 'there are 54 tools used in the 234 pyproject.toml files.'

# %% [markdown]
# the `top12` most frequently defined tools in the `pyproject.toml`s are

# %%
    tool_counts = tools.isna().astype(int).sub(1).abs().sum().sort_values(ascending=False)
    (top12 := tool_counts.iloc[:12]).to_frame("counts").T
# Out:
#         black  isort  pytest  mypy  coverage  poetry  setuptools_scm  hatch  \
# counts    123     85      67    42        34      32              21     15
#
#         setuptools  pylint  towncrier  pyright
# counts          14      14         11       10

# %% [markdown]
# from the perspective of these popular projects:
#
# * there is strong community adoption of `black` and `isort`.
#   from this data it might be a recommended convention to format your code and sort your imports.
# * `pytest`'s third place popularity recommends that we test our projects
# * `mypy` suggests that type hinting is feature of some popular projects
# * `coverage`
# * `poetry`
# * `setuptools_scm`
# * `hatch`
#
# next we find

# %% [markdown]
# ## build systems

# %%
    df["build-system"].dropna().apply(pandas.Series)
# Out:
#                                                                                                  requires  \
# url
# https://github.com/3b1b/manim                                                         [setuptools, wheel]
# https://github.com/deepmind/hanabi-learning-environment   [setuptools, wheel, scikit-build, cmake, ninja]
# https://github.com/miguelgrinberg/Flask-SocketIO                                  [setuptools>=42, wheel]
# https://github.com/pypa/pipx                                                          [hatchling>=0.15.0]
# https://github.com/py-pdf/PyPDF2                                                     [flit_core >=3.2,<4]
# ...                                                                                                   ...
# https://github.com/deepset-ai/haystack                                                 [hatchling>=1.8.0]
# https://github.com/dedupeio/dedupe                                        [setuptools==63, wheel, cython]
# https://github.com/sktime/sktime                                      [setuptools>61, wheel, toml, build]
# https://github.com/enthought/mayavi                      [oldest-supported-numpy, setuptools, vtk, wheel]
# https://github.com/holoviz/datashader                                           [param, pyct, setuptools]
#
#                                                                  build-backend  \
# url
# https://github.com/3b1b/manim                                              NaN
# https://github.com/deepmind/hanabi-learning-environment                    NaN
# https://github.com/miguelgrinberg/Flask-SocketIO         setuptools.build_meta
# https://github.com/pypa/pipx                                   hatchling.build
# https://github.com/py-pdf/PyPDF2                            flit_core.buildapi
# ...                                                                        ...
# https://github.com/deepset-ai/haystack                         hatchling.build
# https://github.com/dedupeio/dedupe                       setuptools.build_meta
# https://github.com/sktime/sktime                         setuptools.build_meta
# https://github.com/enthought/mayavi                                        NaN
# https://github.com/holoviz/datashader                    setuptools.build_meta
#
#                                                         dependencies
# url
# https://github.com/3b1b/manim                                    NaN
# https://github.com/deepmind/hanabi-learning-environment          NaN
# https://github.com/miguelgrinberg/Flask-SocketIO                 NaN
# https://github.com/pypa/pipx                                     NaN
# https://github.com/py-pdf/PyPDF2                                 NaN
# ...                                                              ...
# https://github.com/deepset-ai/haystack                           NaN
# https://github.com/dedupeio/dedupe                               NaN
# https://github.com/sktime/sktime                                 NaN
# https://github.com/enthought/mayavi                              NaN
# https://github.com/holoviz/datashader                            NaN
#
# [173 rows x 3 columns]

# %% [markdown]
# ## into the projects?

# %%
    df.project.dropna().apply(pandas.Series).head(0)
# Out:
# Empty DataFrame
# Columns: [name, description, readme, license, requires-python, keywords, authors, classifiers, dependencies, dynamic, urls, scripts, maintainers, optional-dependencies, entry-points, gui-scripts, version]
# Index: []
