# %%
# `IPython` displays

# %% [markdown]
# ## remember to search for awesome lists

# %%
https://web.archive.org/web/20210324223324/https://github.com/markusschanta/awesome-jupyter#Visualization
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://web.archive.org/web/20210324223324/https://github.com/markusschanta/awesome-jupyter#Visualization"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
#     df = pandas.read_html("https://deathbeds.github.io/wxyz/#install-and-use")[1]
#     print(df["pip or conda install W"].pipe("\n".join))

# %%
    # %%file requirements.txt
    altair
    vega_datasets
    bokeh
    bqplot
    evidently
    ipyleaflet
    ipysheet
    ipywebrtc
    ipywidgets
    ipyvolume
    itkwidgets
    lux-api
    mpld3
    pythreejs
    wxyz_core
    wxyz_datagrid
    wxyz_html
    wxyz_dvcs
    wxyz_json_e
    wxyz_json_schema_form
    wxyz_jsonld
    wxyz_lab
    wxyz_svg
    wxyz_tpl_jinja
    wxyz_yaml
    tributary
    tqdm
    jupyterlab-geojson
# Out:
# Overwriting requirements.txt
#     %%file requirements.txt
#     altair
#     vega_datasets
#     bokeh
#     bqplot
#     evidently
#     ipyleaflet
#     ipysheet
#     ipywebrtc
#     ipywidgets
#     ipyvolume
#     itkwidgets
#     lux-api
#     mpld3
#     pythreejs
#     wxyz_core
#     wxyz_datagrid
#     wxyz_html
#     wxyz_dvcs
#     wxyz_json_e
#     wxyz_json_schema_form
#     wxyz_jsonld
#     wxyz_lab
#     wxyz_svg
#     wxyz_tpl_jinja
#     wxyz_yaml
#     tributary
#     tqdm
#     jupyterlab-geojson

# %%
    import tqdm
    for i in tqdm.tqdm_notebook(range(10)):
        time.sleep(.2)
# Out:
# /home/tonyfast/Documents/pidgy/pidgy/kernel.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import contextlib
#   0%|          | 0/10 [00:00<?, ?it/s]
#     import tqdm
#     for i in tqdm.tqdm_notebook(range(10)):
#         time.sleep(.2)

# %%
## observable notebooks
# Out:
# ## observable notebooks

# %%
https://observablehq.com/@kerryrodden/equal-area-radial-matrix-of-lgbt-rights
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://observablehq.com/@kerryrodden/equal-area-radial-matrix-of-lgbt-rights"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## standards based
## non-standard
