# %% [markdown]
# # shhh! it's a secret! tell your friends
#
# there is a under utilized feature in `jupyter`, it might as well
# be an easter🐰🐤egg.
#
# if you bear with me we'll strike gold.
#
# ![image.png](attachment:991868e2-a4f1-4d43-9163-bc1349ab61b3.png)

# %% [markdown]
# reducing notebooks to code objects or even literary objects does them a disservice. they are multilingual, multimedia canvases for collage. image can be a powerful force in a narrative, but we become burdened with content management resposibilities. this mag🪄c i'm about to show will take away all those aches and pains.

# %% [markdown]
# this punchline is we can paste images directly into markdown cells. 🤯 right? yea, i know. its wild. so what is happening?

# %% [markdown]
# 1. in a markdown cell only
#
# ![image.png](attachment:0f80ec95-0e31-4c1f-a2ea-05b5d9e67ccb.png)
#
# 2. paste an image CTRL+V
#
# 3. `jupyter` saves the image data in the `notebook` data itself
# as an attachment.
#
# ![image.png](attachment:c322f493-619a-4c72-8a69-dcd228ff3fd5.png)
#
#   see it has been in the [`nbformat` schema the whole time](https://github.com/jupyter/nbformat/blob/master/nbformat/v4/nbformat.v4.5.schema.json#L185), but nigh in the docs.
#
# 4. you, the hero of this story, will recieve some text back
#   in the form of a markdown image syntax. it starts with an
#   exclamation because it's :smiley_cat: for you. you'll see
#   sumpin like `"![image.png](attachment:6c412849-cb07-4b64-90cc-a46f56c63dbc.png)"`
#
# ![image.png](attachment:67428999-aa47-4ac8-9578-21647d43d0cb.png)

# %% [markdown]
# ## conclusion
#
# 👏👏👏 we are now enlighted. we know how to make collections
# of images in notebooks with very natural copy paste operations. try
# it out, it feels good.
