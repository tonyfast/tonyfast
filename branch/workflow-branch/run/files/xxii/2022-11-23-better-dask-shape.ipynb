# %% [markdown]
# # unravel directories of notebooks with `dask`

# %% [markdown]
# this is another pass at using `dask` to load notebooks with the ultimate intent to search them.
# in [searching-notebooks](oct/2022-10-05-dask-search.ipynb), i first approach this task with some
# keen `pandas` skills that we not so kind in the `dask` land.
# this document takes another pass at using clearer expressions to ravel a bunch
# of notebooks to `dask.dataframe`
#
# taking care to load notebooks as `dask.dataframe`s offers the power to apply
# direct queries, export to parquet, export to sqlite, export to duckdb, arrow..

# %%
    # %pip install dask orjson toolz pandas jsonpointer jinja2
    import pandas, json, jsonpointer, orjson, dask.dataframe; from pathlib import Path
    from toolz.curried import *
    XXX = __name__ == "__main__" and "__file__" not in locals()

# %% [markdown]
# ## if you know the shape then define it
#
# `dask` truly prefers explicit dtypes while `pandas` is more flexible.
# `meta` holds our shape information for the cells, outputs, and displays

# %%
    class meta: 
        O = "object"
        ANY = None, O
        NB = [("cells", O), ("metadata", O), ("nbformat", int), ("nbformat_minor", int)]
        CELL = [
            ("cell_type", str), ("execution_count", int), ("id", str),
            ("metadata", O), ("outputs", O), ("source", str), ("cell_ct", int),]
        OUTPUT = [
            ("data", O), ("metadata", O), ("ename", str), ("evalue", str),
            ("text", str), ("execution_count", int), ("output_type", str), ("output_ct", int)]
        DISPLAY = [("type", str), ("value", str)]        
        new_nb = pandas.Series(index=map(first, NB), dtype="O")
        new_cell = pandas.Series(index=map(first, CELL), dtype="O")
        new_output = pandas.Series(index=map(first, OUTPUT), dtype="O")
        new_display = pandas.Series(index=map(first, DISPLAY), dtype="O")
    def enumerate_list(x, key="cell_ct"): return [{key: i, **y} for i, y in enumerate(x)]    

    def get_series(data, key="text", new=meta.new_output):
        if key in data:
            data[key] = "".join(data[key])
        s = new.copy()
        return s.update(data) or s

# %% [markdown]
# off to the races as we load some data from our local files.

# %%
    WHERE = Path("oct")

# %% [markdown]
# the files we include start and remain our index. in prior iterations, there were a few set index operations, but we don't want to be opening files to do this cause that is costly. we'll store other metadata on the dataframe as we unpack the notebook shapes.

# %%
    def get_files(WHERE=WHERE):
        return dask.bag.from_sequence(
            dict(file=str(x)) for x in WHERE.glob("*.ipynb")
        ).to_dataframe().set_index("file")
    XXX and (files := get_files())
# Out:
# Empty Dask DataFrame Structure:
# Columns: []
# Divisions: [oct/2022-10-05-dask-search.ipynb, oct/2022-10-06-github-open-source-stats.ipynb, oct/2022-10-19-mobius-text.ipynb, oct/2022-10-20-meeting-link-widgets.ipynb, oct/2022-10-21-markdown-future.ipynb, oct/2022-10-21-pidgy-displays.ipynb, oct/2022-10-25-static-notebook-tags.ipynb, oct/2022-10-26-metadata-formatter-Copy1.ipynb, oct/2022-10-27-.ipynb, oct/2022-10-27-axe-core-playwright-python.ipynb, oct/2022-10-29-.ipynb, oct/2022-10-29-metadata-formatter.ipynb, oct/2022-10-29-notebook-files-to-parquet.ipynb, oct/2022-10-31-.ipynb, oct/2022-10-31-1.ipynb, oct/2022-11-17--Copy1.ipynb, oct/2022-11-17-1.ipynb, oct/2022-11-17-assignment-expression-display.ipynb, oct/2022-11-21-.ipynb, oct/2022-11-21-1.ipynb, oct/test_nbconvert_html5.ipynb]
# Dask Name: sort_index, 8 graph layers

# %% [markdown]
# `contents` loads our files in to a dataframe containg real cell contents.
# each row is a file.

# %%
    def get_contents_from_files(files):
        return  files.index.to_series().apply(
            compose_left(Path, Path.read_text, orjson.loads, partial(
                get_series, new=meta.new_nb)), meta=meta.NB)
    XXX and (contents := get_contents_from_files(files))
# Out:
# Dask DataFrame Structure:
#                                                 cells metadata nbformat nbformat_minor
# npartitions=20
# oct/2022-10-05-dask-search.ipynb               object   object    int64          int64
# oct/2022-10-06-github-open-source-stats.ipynb     ...      ...      ...            ...
# ...                                               ...      ...      ...            ...
# oct/2022-11-21-1.ipynb                            ...      ...      ...            ...
# oct/test_nbconvert_html5.ipynb                    ...      ...      ...            ...
# Dask Name: apply, 11 graph layers

# %% [markdown]
# the `cells` are built by exploding the rows of the `contents`

# %%
    def get_cells_from_contents(contents):
        cells = contents.cells
        cells = cells.apply(enumerate_list, meta=meta.ANY)
        return cells.explode().apply(get_series, key="source", new=meta.new_cell, meta=meta.CELL)
    if XXX:
        cells = get_cells_from_contents(contents)    
        meta_cells = cells["metadata cell_ct".split()]; cells.pop("metadata"); display(cells)
# Out:
# Dask DataFrame Structure:
#                                               cell_type execution_count      id outputs  source cell_ct
# npartitions=20
# oct/2022-10-05-dask-search.ipynb                 object           int64  object  object  object   int64
# oct/2022-10-06-github-open-source-stats.ipynb       ...             ...     ...     ...     ...     ...
# ...                                                 ...             ...     ...     ...     ...     ...
# oct/2022-11-21-1.ipynb                              ...             ...     ...     ...     ...     ...
# oct/test_nbconvert_html5.ipynb                      ...             ...     ...     ...     ...     ...
# Dask Name: drop_by_shallow_copy, 16 graph layers

# %% [markdown]
# new we deal will outputs that include display_data, stdout, and stderr.

# %%
    def get_outputs_from_cells(cells):
        outputs = cells["outputs cell_ct".split()].dropna(subset="outputs")
        outputs.outputs = outputs.outputs.apply(enumerate_list, key="output_ct", meta=meta.ANY)
        outputs = outputs.explode("outputs").dropna(subset="outputs")
        return dask.dataframe.concat([
            outputs.pop("outputs").apply(get_series, key="text", new=meta.new_output, meta=meta.OUTPUT),
            outputs
        ], axis=1)
    if XXX:
        outputs = get_outputs_from_cells(cells)
        meta_display = outputs["metadata cell_ct output_ct".split()]; outputs.pop("metadata"); display(outputs)
# Out:
# Dask DataFrame Structure:
#                                                  data   ename  evalue    text execution_count output_type output_ct cell_ct
# npartitions=20
# oct/2022-10-05-dask-search.ipynb               object  object  object  object           int64      object     int64   int64
# oct/2022-10-06-github-open-source-stats.ipynb     ...     ...     ...     ...             ...         ...       ...     ...
# ...                                               ...     ...     ...     ...             ...         ...       ...     ...
# oct/2022-11-21-1.ipynb                            ...     ...     ...     ...             ...         ...       ...     ...
# oct/test_nbconvert_html5.ipynb                    ...     ...     ...     ...             ...         ...       ...     ...
# Dask Name: drop_by_shallow_copy, 2 graph layers

# %% [markdown]
# separating the different standard out/error displays from the rich display data. there is probably more to for managing the different types of outputs from the different reprs.

# %%
    def get_display_data_from_outputs(outputs):
        display_data = outputs["data execution_count output_type cell_ct output_ct".split()].dropna(subset="data")
        display_data["data"] = display_data["data"].apply(compose_left(dict.items, list), meta=meta.ANY)
        display_data = display_data.explode("data").dropna(subset="data")
        return dask.dataframe.concat([
            display_data.pop("data").apply(
                compose_left(
                    partial(zip, meta.new_display.index), dict, 
                    partial(get_series, key=None, new=meta.new_display)
                ), meta=meta.DISPLAY), display_data], axis=1)
    XXX and (display_data := get_display_data_from_outputs(outputs)).compute()
# Out:
#                                                                       type  \
# file
# oct/2022-10-05-dask-search.ipynb                                text/plain
# oct/2022-10-05-dask-search.ipynb                                 text/html
# oct/2022-10-05-dask-search.ipynb                                text/plain
# oct/2022-10-05-dask-search.ipynb                                 text/html
# oct/2022-10-05-dask-search.ipynb                                text/plain
# ...                                                                    ...
# oct/2022-11-21-1.ipynb            application/vnd.jupyter.widget-view+json
# oct/2022-11-21-1.ipynb                                          text/plain
# oct/test_nbconvert_html5.ipynb                                  text/plain
# oct/test_nbconvert_html5.ipynb                                  text/plain
# oct/test_nbconvert_html5.ipynb                                  text/plain
#
#                                                                               value  \
# file
# oct/2022-10-05-dask-search.ipynb  ["the expected cell keys are ['attachments', '...
# oct/2022-10-05-dask-search.ipynb  [<div><strong>Dask DataFrame Structure:</stron...
# oct/2022-10-05-dask-search.ipynb  [Dask DataFrame Structure:\n,               at...
# oct/2022-10-05-dask-search.ipynb  [<div>\n, <style scoped>\n,     .dataframe tbo...
# oct/2022-10-05-dask-search.ipynb  [path                                       .....
# ...                                                                             ...
# oct/2022-11-21-1.ipynb            {'model_id': 'cd4f96b3078c4adf851d419b9c8e7885...
# oct/2022-11-21-1.ipynb            [HTML(value='<pre><code>importlib._bootstrap_e...
# oct/test_nbconvert_html5.ipynb                                            [([], 1)]
# oct/test_nbconvert_html5.ipynb                                           [([], 16)]
# oct/test_nbconvert_html5.ipynb                                            [([], 5)]
#
#                                   execution_count     output_type  cell_ct  \
# file
# oct/2022-10-05-dask-search.ipynb              3.0  execute_result        7
# oct/2022-10-05-dask-search.ipynb              NaN    display_data       15
# oct/2022-10-05-dask-search.ipynb              NaN    display_data       15
# oct/2022-10-05-dask-search.ipynb              NaN    display_data       17
# oct/2022-10-05-dask-search.ipynb              NaN    display_data       17
# ...                                           ...             ...      ...
# oct/2022-11-21-1.ipynb                        NaN    display_data        4
# oct/2022-11-21-1.ipynb                        NaN    display_data        4
# oct/test_nbconvert_html5.ipynb                4.0  execute_result        5
# oct/test_nbconvert_html5.ipynb                5.0  execute_result        7
# oct/test_nbconvert_html5.ipynb                6.0  execute_result        9
#
#                                   output_ct
# file
# oct/2022-10-05-dask-search.ipynb          0
# oct/2022-10-05-dask-search.ipynb          1
# oct/2022-10-05-dask-search.ipynb          1
# oct/2022-10-05-dask-search.ipynb          0
# oct/2022-10-05-dask-search.ipynb          0
# ...                                     ...
# oct/2022-11-21-1.ipynb                    1
# oct/2022-11-21-1.ipynb                    1
# oct/test_nbconvert_html5.ipynb            0
# oct/test_nbconvert_html5.ipynb            0
# oct/test_nbconvert_html5.ipynb            0
#
# [173 rows x 6 columns]

# %% [markdown]
# ## where to go from
#
# * extend to other files. the notebook format is a hypermedia document format.
# * save to different formats. initially we think about parquet, while in theory from this dataframe
# we could go further an imagine it being the seed for documentation.

# %%
    XXX and display(*(x.sample(frac=.1).compute().sample(5) for x in (cells, outputs, display_data)))
# Out:
#                                                 cell_type  execution_count  \
# file
# oct/2022-10-29-metadata-formatter.ipynb          markdown              NaN
# oct/2022-10-06-github-open-source-stats.ipynb        code            197.0
# oct/2022-10-21-markdown-future.ipynb                 code              5.0
# oct/2022-10-19-mobius-text.ipynb                     code              NaN
# oct/2022-10-27-axe-core-playwright-python.ipynb      code             17.0
#
#                                                                                    id  \
# file
# oct/2022-10-29-metadata-formatter.ipynb          50d9dcf9-18f4-4eb7-9a9a-cc3e14b3b2e2
# oct/2022-10-06-github-open-source-stats.ipynb    af8301f0-8a28-4350-87fa-a728867ccf67
# oct/2022-10-21-markdown-future.ipynb             21fa2ad9-23f9-4868-9cb7-3bb87b69c542
# oct/2022-10-19-mobius-text.ipynb                 55228766-71c2-48f0-819f-afab637a4867
# oct/2022-10-27-axe-core-playwright-python.ipynb  6e7cb333-6cc3-4c73-b256-382bcb3e9c2c
#
#                                                                                            outputs  \
# file
# oct/2022-10-29-metadata-formatter.ipynb                                                        NaN
# oct/2022-10-06-github-open-source-stats.ipynb                                                   []
# oct/2022-10-21-markdown-future.ipynb             [{'data': {'text/markdown': ['# tangle (code) ...
# oct/2022-10-19-mobius-text.ipynb                                                                []
# oct/2022-10-27-axe-core-playwright-python.ipynb                                                 []
#
#                                                                                             source  \
# file
# oct/2022-10-29-metadata-formatter.ipynb                                            #### dataframes
# oct/2022-10-06-github-open-source-stats.ipynb                                     %reload_ext doit
# oct/2022-10-21-markdown-future.ipynb             # tangle (code) and weave (display)\n\n    kni...
# oct/2022-10-19-mobius-text.ipynb
# oct/2022-10-27-axe-core-playwright-python.ipynb  async def injectAxe(page): \n    await page.ev...
#
#                                                  cell_ct
# file
# oct/2022-10-29-metadata-formatter.ipynb               16
# oct/2022-10-06-github-open-source-stats.ipynb          6
# oct/2022-10-21-markdown-future.ipynb                   7
# oct/2022-10-19-mobius-text.ipynb                      18
# oct/2022-10-27-axe-core-playwright-python.ipynb        9
#                                                                                    data  \
# file
# oct/2022-10-21-markdown-future.ipynb  {'text/markdown': ['i'm not saying importing m...
# oct/2022-11-17--Copy1.ipynb           {'application/vnd.jupyter.widget-view+json': {...
# oct/2022-10-21-markdown-future.ipynb  {'text/markdown': ['```mermaid
# ', 'flowchart L...
# oct/2022-10-29-.ipynb                                                               NaN
# oct/2022-10-21-pidgy-displays.ipynb   {'application/vnd.jupyter.widget-view+json': {...
#
#                                                ename  \
# file
# oct/2022-10-21-markdown-future.ipynb             NaN
# oct/2022-11-17--Copy1.ipynb                      NaN
# oct/2022-10-21-markdown-future.ipynb             NaN
# oct/2022-10-29-.ipynb                 AttributeError
# oct/2022-10-21-pidgy-displays.ipynb              NaN
#
#                                                                        evalue  \
# file
# oct/2022-10-21-markdown-future.ipynb                                      NaN
# oct/2022-11-17--Copy1.ipynb                                               NaN
# oct/2022-10-21-markdown-future.ipynb                                      NaN
# oct/2022-10-29-.ipynb                 'dict' object has no attribute 'breaks'
# oct/2022-10-21-pidgy-displays.ipynb                                       NaN
#
#                                      text  execution_count   output_type  \
# file
# oct/2022-10-21-markdown-future.ipynb  NaN              NaN  display_data
# oct/2022-11-17--Copy1.ipynb           NaN              NaN  display_data
# oct/2022-10-21-markdown-future.ipynb  NaN              NaN  display_data
# oct/2022-10-29-.ipynb                 NaN              NaN         error
# oct/2022-10-21-pidgy-displays.ipynb   NaN              NaN  display_data
#
#                                       output_ct  cell_ct
# file
# oct/2022-10-21-markdown-future.ipynb          0       17
# oct/2022-11-17--Copy1.ipynb                   0        6
# oct/2022-10-21-markdown-future.ipynb          1       16
# oct/2022-10-29-.ipynb                         1       12
# oct/2022-10-21-pidgy-displays.ipynb           0       17
#                                                                           type  \
# file
# oct/2022-10-05-dask-search.ipynb                                     text/html
# oct/2022-11-21-1.ipynb                                              text/plain
# oct/2022-10-29-.ipynb                 application/vnd.jupyter.widget-view+json
# oct/2022-11-17--Copy1.ipynb                                         text/plain
# oct/2022-10-21-markdown-future.ipynb                             text/markdown
#
#                                                                                   value  \
# file
# oct/2022-10-05-dask-search.ipynb      [<div>\n, <style scoped>\n,     .dataframe tbo...
# oct/2022-11-21-1.ipynb                     [HTML(value='<pre><code>__</code></pre>\n')]
# oct/2022-10-29-.ipynb                 {'model_id': 'fa05bd5e43cc4785834b4b87ec154fbe...
# oct/2022-11-17--Copy1.ipynb           [HTML(value='<pre><code>notebooks = pandas.con...
# oct/2022-10-21-markdown-future.ipynb  [## literate computing with literary machines ...
#
#                                       execution_count   output_type  cell_ct  \
# file
# oct/2022-10-05-dask-search.ipynb                  NaN  display_data       19
# oct/2022-11-21-1.ipynb                            NaN  display_data        2
# oct/2022-10-29-.ipynb                             NaN  display_data       11
# oct/2022-11-17--Copy1.ipynb                       NaN  display_data        5
# oct/2022-10-21-markdown-future.ipynb              NaN  display_data        5
#
#                                       output_ct
# file
# oct/2022-10-05-dask-search.ipynb              0
# oct/2022-11-21-1.ipynb                        1
# oct/2022-10-29-.ipynb                         0
# oct/2022-11-17--Copy1.ipynb                   0
# oct/2022-10-21-markdown-future.ipynb          0

# %%
    from dataclasses import dataclass, field
    @dataclass
    class Contents:
        dir: Path = field(default_factory=Path.cwd)
        contents: dask.dataframe.DataFrame = None
        
        def __post_init__(self):
            self.contents = get_contents_from_files(get_files(self.dir))
            self.cells = get_cells_from_contents(self.contents)
            self.outputs = get_outputs_from_cells(self.cells)
            self.display_data = self.get_display_data_from_outputs(self.outputs)
